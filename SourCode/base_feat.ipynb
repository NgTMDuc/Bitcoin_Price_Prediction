# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import sys
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.metrics import roc_auc_score 
import warnings
warnings.filterwarnings("ignore")

# %%
from label import label

# %%
df = label('D:\\Project\\Bitcoin_Price_Prediction\\data\\binance-BTCUSDT-1m.csv', t=15)

# %%
df
# Out:
#                    Open      High       Low     Close      Volumn  \
# Timestamp
# 1531910340000   7370.00   7404.23   7365.10   7402.13  421.446875
# 1531911240000   7404.23   7419.09   7393.03   7398.00  400.220193
# 1531912140000   7397.00   7413.67   7388.97   7401.99  283.424582
# 1531913040000   7401.99   7433.32   7395.00   7430.33  385.377189
# 1531913940000   7430.33   7433.58   7408.07   7418.00  412.557017
# ...                 ...       ...       ...       ...         ...
# 1651905540000  35858.19  35878.00  35795.54  35795.55  231.841700
# 1651906440000  35795.54  35832.12  35790.02  35812.80  154.689420
# 1651907340000  35812.81  35870.00  35800.00  35867.66  613.847520
# 1651908240000  35867.65  35912.00  35826.36  35902.74  330.432300
# 1651909140000  35902.75  35956.51  35880.47  35951.69  368.392130
#
#                Timestamp End  Quote_asset_volume  Number_of_trades  \
# Timestamp
# 1531910340000  1531911239999        3.112218e+06              2210
# 1531911240000  1531912139999        2.963666e+06              2825
# 1531912140000  1531913039999        2.097944e+06              2022
# 1531913040000  1531913939999        2.858399e+06              2194
# 1531913940000  1531914839999        3.061536e+06              2352
# ...                      ...                 ...               ...
# 1651905540000  1651906439999        8.311628e+06              5817
# 1651906440000  1651907339999        5.539456e+06              5981
# 1651907340000  1651908239999        2.198320e+07              7098
# 1651908240000  1651909139999        1.185255e+07              5798
# 1651909140000  1651910039999        1.323538e+07              7430
#
#                Base_asset_volume  Taker_buy_base_asset_volume  \
# Timestamp
# 1531910340000         244.531743                 1.805624e+06
# 1531911240000         217.698269                 1.612081e+06
# 1531912140000         158.367674                 1.172256e+06
# 1531913040000         230.656692                 1.711215e+06
# 1531913940000         231.403556                 1.717226e+06
# ...                          ...                          ...
# 1651905540000          86.377500                 3.096591e+06
# 1651906440000          91.672010                 3.282832e+06
# 1651907340000         179.258800                 6.422060e+06
# 1651908240000         194.712580                 6.983194e+06
# 1651909140000         228.147900                 8.196411e+06
#
#                     Time_UTC_Start  label
# Timestamp
# 1531910340000  2018-07-18 10:39:00    1.0
# 1531911240000  2018-07-18 10:54:00    0.0
# 1531912140000  2018-07-18 11:09:00    1.0
# 1531913040000  2018-07-18 11:24:00    1.0
# 1531913940000  2018-07-18 11:39:00    0.0
# ...                            ...    ...
# 1651905540000  2022-05-07 06:39:00    0.0
# 1651906440000  2022-05-07 06:54:00    1.0
# 1651907340000  2022-05-07 07:09:00    1.0
# 1651908240000  2022-05-07 07:24:00    1.0
# 1651909140000  2022-05-07 07:39:00    1.0
#
# [133333 rows x 12 columns]

# %%
del df['Timestamp End'], df['Time_UTC_Start']

# %%
df
# Out:
#                    Open      High       Low     Close      Volumn  \
# Timestamp
# 1531910340000   7370.00   7404.23   7365.10   7402.13  421.446875
# 1531911240000   7404.23   7419.09   7393.03   7398.00  400.220193
# 1531912140000   7397.00   7413.67   7388.97   7401.99  283.424582
# 1531913040000   7401.99   7433.32   7395.00   7430.33  385.377189
# 1531913940000   7430.33   7433.58   7408.07   7418.00  412.557017
# ...                 ...       ...       ...       ...         ...
# 1651905540000  35858.19  35878.00  35795.54  35795.55  231.841700
# 1651906440000  35795.54  35832.12  35790.02  35812.80  154.689420
# 1651907340000  35812.81  35870.00  35800.00  35867.66  613.847520
# 1651908240000  35867.65  35912.00  35826.36  35902.74  330.432300
# 1651909140000  35902.75  35956.51  35880.47  35951.69  368.392130
#
#                Quote_asset_volume  Number_of_trades  Base_asset_volume  \
# Timestamp
# 1531910340000        3.112218e+06              2210         244.531743
# 1531911240000        2.963666e+06              2825         217.698269
# 1531912140000        2.097944e+06              2022         158.367674
# 1531913040000        2.858399e+06              2194         230.656692
# 1531913940000        3.061536e+06              2352         231.403556
# ...                           ...               ...                ...
# 1651905540000        8.311628e+06              5817          86.377500
# 1651906440000        5.539456e+06              5981          91.672010
# 1651907340000        2.198320e+07              7098         179.258800
# 1651908240000        1.185255e+07              5798         194.712580
# 1651909140000        1.323538e+07              7430         228.147900
#
#                Taker_buy_base_asset_volume  label
# Timestamp
# 1531910340000                 1.805624e+06    1.0
# 1531911240000                 1.612081e+06    0.0
# 1531912140000                 1.172256e+06    1.0
# 1531913040000                 1.711215e+06    1.0
# 1531913940000                 1.717226e+06    0.0
# ...                                    ...    ...
# 1651905540000                 3.096591e+06    0.0
# 1651906440000                 3.282832e+06    1.0
# 1651907340000                 6.422060e+06    1.0
# 1651908240000                 6.983194e+06    1.0
# 1651909140000                 8.196411e+06    1.0
#
# [133333 rows x 10 columns]

# %% [markdown]
# #### Itegrate = 1

# %%
df['Open_change'] = df['Open'] - df['Open'].shift(1)
df['High_change'] = df['High'] - df['High'].shift(1)
df['Low_change'] = df['Low'] - df['Low'].shift(1)
df['Close_change'] = df['Close'] - df['Close'].shift(1)
df = df.dropna()

# %%
df
# Out:
#                    Open      High       Low     Close      Volumn  \
# Timestamp
# 1531911240000   7404.23   7419.09   7393.03   7398.00  400.220193
# 1531912140000   7397.00   7413.67   7388.97   7401.99  283.424582
# 1531913040000   7401.99   7433.32   7395.00   7430.33  385.377189
# 1531913940000   7430.33   7433.58   7408.07   7418.00  412.557017
# 1531914840000   7417.99   7429.22   7406.23   7418.29  396.608081
# ...                 ...       ...       ...       ...         ...
# 1651905540000  35858.19  35878.00  35795.54  35795.55  231.841700
# 1651906440000  35795.54  35832.12  35790.02  35812.80  154.689420
# 1651907340000  35812.81  35870.00  35800.00  35867.66  613.847520
# 1651908240000  35867.65  35912.00  35826.36  35902.74  330.432300
# 1651909140000  35902.75  35956.51  35880.47  35951.69  368.392130
#
#                Quote_asset_volume  Number_of_trades  Base_asset_volume  \
# Timestamp
# 1531911240000        2.963666e+06              2825         217.698269
# 1531912140000        2.097944e+06              2022         158.367674
# 1531913040000        2.858399e+06              2194         230.656692
# 1531913940000        3.061536e+06              2352         231.403556
# 1531914840000        2.942861e+06              2025         243.197524
# ...                           ...               ...                ...
# 1651905540000        8.311628e+06              5817          86.377500
# 1651906440000        5.539456e+06              5981          91.672010
# 1651907340000        2.198320e+07              7098         179.258800
# 1651908240000        1.185255e+07              5798         194.712580
# 1651909140000        1.323538e+07              7430         228.147900
#
#                Taker_buy_base_asset_volume  label  Open_change  High_change  \
# Timestamp
# 1531911240000                 1.612081e+06    0.0        34.23        14.86
# 1531912140000                 1.172256e+06    1.0        -7.23        -5.42
# 1531913040000                 1.711215e+06    1.0         4.99        19.65
# 1531913940000                 1.717226e+06    0.0        28.34         0.26
# 1531914840000                 1.804689e+06    1.0       -12.34        -4.36
# ...                                    ...    ...          ...          ...
# 1651905540000                 3.096591e+06    0.0        51.05        11.85
# 1651906440000                 3.282832e+06    1.0       -62.65       -45.88
# 1651907340000                 6.422060e+06    1.0        17.27        37.88
# 1651908240000                 6.983194e+06    1.0        54.84        42.00
# 1651909140000                 8.196411e+06    1.0        35.10        44.51
#
#                Low_change  Close_change
# Timestamp
# 1531911240000       27.93         -4.13
# 1531912140000       -4.06          3.99
# 1531913040000        6.03         28.34
# 1531913940000       13.07        -12.33
# 1531914840000       -1.84          0.29
# ...                   ...           ...
# 1651905540000        1.23        -62.64
# 1651906440000       -5.52         17.25
# 1651907340000        9.98         54.86
# 1651908240000       26.36         35.08
# 1651909140000       54.11         48.95
#
# [133332 rows x 14 columns]

# %%
df['Close_change'].shift(1).rolling(3).agg({"min_close":'min', 'max_close':'max'})
# Out:
#                min_close  max_close
# Timestamp
# 1531911240000        NaN        NaN
# 1531912140000        NaN        NaN
# 1531913040000        NaN        NaN
# 1531913940000      -4.13      28.34
# 1531914840000     -12.33      28.34
# ...                  ...        ...
# 1651905540000     -43.84      51.04
# 1651906440000     -62.64      51.04
# 1651907340000     -62.64      51.04
# 1651908240000     -62.64      54.86
# 1651909140000      17.25      54.86
#
# [133332 rows x 2 columns]

# %%
df.head()
# Out:
#                   Open     High      Low    Close      Volumn  \
# Timestamp
# 1531911240000  7404.23  7419.09  7393.03  7398.00  400.220193
# 1531912140000  7397.00  7413.67  7388.97  7401.99  283.424582
# 1531913040000  7401.99  7433.32  7395.00  7430.33  385.377189
# 1531913940000  7430.33  7433.58  7408.07  7418.00  412.557017
# 1531914840000  7417.99  7429.22  7406.23  7418.29  396.608081
#
#                Quote_asset_volume  Number_of_trades  Base_asset_volume  \
# Timestamp
# 1531911240000        2.963666e+06              2825         217.698269
# 1531912140000        2.097944e+06              2022         158.367674
# 1531913040000        2.858399e+06              2194         230.656692
# 1531913940000        3.061536e+06              2352         231.403556
# 1531914840000        2.942861e+06              2025         243.197524
#
#                Taker_buy_base_asset_volume  label  Open_change  High_change  \
# Timestamp
# 1531911240000                 1.612081e+06    0.0        34.23        14.86
# 1531912140000                 1.172256e+06    1.0        -7.23        -5.42
# 1531913040000                 1.711215e+06    1.0         4.99        19.65
# 1531913940000                 1.717226e+06    0.0        28.34         0.26
# 1531914840000                 1.804689e+06    1.0       -12.34        -4.36
#
#                Low_change  Close_change
# Timestamp
# 1531911240000       27.93         -4.13
# 1531912140000       -4.06          3.99
# 1531913040000        6.03         28.34
# 1531913940000       13.07        -12.33
# 1531914840000       -1.84          0.29

# %%
df['Close_change']
# Out:
# Timestamp
# 1531911240000    -4.13
# 1531912140000     3.99
# 1531913040000    28.34
# 1531913940000   -12.33
# 1531914840000     0.29
#                  ...
# 1651905540000   -62.64
# 1651906440000    17.25
# 1651907340000    54.86
# 1651908240000    35.08
# 1651909140000    48.95
# Name: Close_change, Length: 133332, dtype: float64

# %%
base_cols = list(df.columns)

# %%
base_cols
# Out:
# ['Open',
#  'High',
#  'Low',
#  'Close',
#  'Volumn',
#  'Quote_asset_volume',
#  'Number_of_trades',
#  'Base_asset_volume',
#  'Taker_buy_base_asset_volume',
#  'label',
#  'Open_change',
#  'High_change',
#  'Low_change',
#  'Close_change']

# %%
base_cols = base_cols[4:]

# %%
base_cols
# Out:
# ['Volumn',
#  'Quote_asset_volume',
#  'Number_of_trades',
#  'Base_asset_volume',
#  'Taker_buy_base_asset_volume',
#  'label',
#  'Open_change',
#  'High_change',
#  'Low_change',
#  'Close_change']

# %%
df
# Out:
#                    Open      High       Low     Close      Volumn  \
# Timestamp
# 1531911240000   7404.23   7419.09   7393.03   7398.00  400.220193
# 1531912140000   7397.00   7413.67   7388.97   7401.99  283.424582
# 1531913040000   7401.99   7433.32   7395.00   7430.33  385.377189
# 1531913940000   7430.33   7433.58   7408.07   7418.00  412.557017
# 1531914840000   7417.99   7429.22   7406.23   7418.29  396.608081
# ...                 ...       ...       ...       ...         ...
# 1651905540000  35858.19  35878.00  35795.54  35795.55  231.841700
# 1651906440000  35795.54  35832.12  35790.02  35812.80  154.689420
# 1651907340000  35812.81  35870.00  35800.00  35867.66  613.847520
# 1651908240000  35867.65  35912.00  35826.36  35902.74  330.432300
# 1651909140000  35902.75  35956.51  35880.47  35951.69  368.392130
#
#                Quote_asset_volume  Number_of_trades  Base_asset_volume  \
# Timestamp
# 1531911240000        2.963666e+06              2825         217.698269
# 1531912140000        2.097944e+06              2022         158.367674
# 1531913040000        2.858399e+06              2194         230.656692
# 1531913940000        3.061536e+06              2352         231.403556
# 1531914840000        2.942861e+06              2025         243.197524
# ...                           ...               ...                ...
# 1651905540000        8.311628e+06              5817          86.377500
# 1651906440000        5.539456e+06              5981          91.672010
# 1651907340000        2.198320e+07              7098         179.258800
# 1651908240000        1.185255e+07              5798         194.712580
# 1651909140000        1.323538e+07              7430         228.147900
#
#                Taker_buy_base_asset_volume  label  Open_change  High_change  \
# Timestamp
# 1531911240000                 1.612081e+06    0.0        34.23        14.86
# 1531912140000                 1.172256e+06    1.0        -7.23        -5.42
# 1531913040000                 1.711215e+06    1.0         4.99        19.65
# 1531913940000                 1.717226e+06    0.0        28.34         0.26
# 1531914840000                 1.804689e+06    1.0       -12.34        -4.36
# ...                                    ...    ...          ...          ...
# 1651905540000                 3.096591e+06    0.0        51.05        11.85
# 1651906440000                 3.282832e+06    1.0       -62.65       -45.88
# 1651907340000                 6.422060e+06    1.0        17.27        37.88
# 1651908240000                 6.983194e+06    1.0        54.84        42.00
# 1651909140000                 8.196411e+06    1.0        35.10        44.51
#
#                Low_change  Close_change
# Timestamp
# 1531911240000       27.93         -4.13
# 1531912140000       -4.06          3.99
# 1531913040000        6.03         28.34
# 1531913940000       13.07        -12.33
# 1531914840000       -1.84          0.29
# ...                   ...           ...
# 1651905540000        1.23        -62.64
# 1651906440000       -5.52         17.25
# 1651907340000        9.98         54.86
# 1651908240000       26.36         35.08
# 1651909140000       54.11         48.95
#
# [133332 rows x 14 columns]

# %%
base_cols.remove('label')

# %%
import gc
def base_feat(df, base_cols=[], 
                  time_delta=1, 
                  window_lookback=[5, 10, 60, 200, 500],
                  agg_func=['min', 'max', 'mean', 'median', 'var']):
    """
    This func use for create formal features base on a list of columns
    Params:
        df (Pandas DF): dataframe input
        base_cols (list): list of columns you want to create feature by this function
        time_delta (int): time between 2 records (minutes)
        window_lookback (list): list of integer time the time_delta. For example time_delta = 15 window_lookback = [1, 2]
                                so the time lookback is 15 minutes and 15*2=30 minutes
        agg_func (list): aggregate func you use for rolling
    """
        
    for col in base_cols:
        for lookback in window_lookback:
            dict_agg_func = {'_'.join([agg, col, str(time_delta * lookback) + 'M']): agg for agg in agg_func}
            df_feat = df[col].shift(1).rolling(lookback).agg(dict_agg_func)
            df = pd.concat([df, df_feat], axis=1)
            del df_feat
            gc.collect()
    for col in df.columns:
        if '1' in col and 'var' in col:
            del df[col]
    df = df.dropna()
    return df

# %%
df_feat = base_feat(df, base_cols=base_cols)

# %%
df_feat.head()
# Out:
#                   Open     High      Low    Close      Volumn  \
# Timestamp
# 1532361240000  7741.13  7747.21  7725.02  7731.00  380.066531
# 1532362140000  7731.00  7743.34  7698.02  7729.15  658.501311
# 1532363040000  7735.58  7749.00  7722.73  7729.99  287.894207
# 1532363940000  7730.49  7740.00  7723.00  7733.17  217.210836
# 1532364840000  7734.98  7745.01  7732.77  7745.00  383.939547
#
#                Quote_asset_volume  Number_of_trades  Base_asset_volume  \
# Timestamp
# 1532361240000        2.939918e+06              2292         193.695606
# 1532362140000        5.082207e+06              2913         323.362969
# 1532363040000        2.227859e+06              2367         128.856921
# 1532363940000        1.679909e+06              1968         130.330289
# 1532364840000        2.971080e+06              2262         273.541665
#
#                Taker_buy_base_asset_volume  label  ...  min_Close_change_200M  \
# Timestamp                                          ...
# 1532361240000                 1.498316e+06    0.0  ...                -126.52
# 1532362140000                 2.496556e+06    0.0  ...                -126.52
# 1532363040000                 9.972310e+05    0.0  ...                -126.52
# 1532363940000                 1.008019e+06    1.0  ...                -126.52
# 1532364840000                 2.116857e+06    1.0  ...                -126.52
#
#                max_Close_change_200M  mean_Close_change_200M  \
# Timestamp
# 1532361240000                  78.07                 1.95045
# 1532362140000                  78.07                 1.75540
# 1532363040000                  78.07                 1.79495
# 1532363940000                  78.07                 1.82495
# 1532364840000                  78.07                 1.88505
#
#                median_Close_change_200M  var_Close_change_200M  \
# Timestamp
# 1532361240000                     1.545             318.598521
# 1532362140000                     1.410             315.653335
# 1532363040000                     1.410             315.050730
# 1532363940000                     1.410             314.811336
# 1532364840000                     1.545             314.245369
#
#                min_Close_change_500M  max_Close_change_500M  \
# Timestamp
# 1532361240000                -174.83                 119.77
# 1532362140000                -174.83                 119.77
# 1532363040000                -174.83                 119.77
# 1532363940000                -174.83                 119.77
# 1532364840000                -174.83                 119.77
#
#                mean_Close_change_500M  median_Close_change_500M  \
# Timestamp
# 1532361240000                 0.67802                     1.090
# 1532362140000                 0.66600                     1.090
# 1532363040000                 0.65432                     0.995
# 1532363940000                 0.59932                     0.920
# 1532364840000                 0.63034                     0.995
#
#                var_Close_change_500M
# Timestamp
# 1532361240000             574.188493
# 1532362140000             574.376550
# 1532363040000             574.366957
# 1532363940000             572.827929
# 1532364840000             572.505307
#
# [5 rows x 230 columns]

# %%
feat = df_feat.columns[14:]

# %%
df_feat.shape
# Out:
# (132832, 230)

# %%
feat
# Out:
# Index(['min_Volumn_5M', 'max_Volumn_5M', 'mean_Volumn_5M', 'median_Volumn_5M',
#        'var_Volumn_5M', 'min_Volumn_10M', 'max_Volumn_10M', 'mean_Volumn_10M',
#        'median_Volumn_10M', 'min_Volumn_60M',
#        ...
#        'min_Close_change_200M', 'max_Close_change_200M',
#        'mean_Close_change_200M', 'median_Close_change_200M',
#        'var_Close_change_200M', 'min_Close_change_500M',
#        'max_Close_change_500M', 'mean_Close_change_500M',
#        'median_Close_change_500M', 'var_Close_change_500M'],
#       dtype='object', length=216)

# %% [markdown]
# # Test features

# %%
for f in feat:
    scaler = preprocessing.StandardScaler()
    df_feat[f] = scaler.fit_transform(df_feat[[f]])

# %%
df_feat.head()
# Out:
#                   Open     High      Low    Close      Volumn  \
# Timestamp
# 1532361240000  7741.13  7747.21  7725.02  7731.00  380.066531
# 1532362140000  7731.00  7743.34  7698.02  7729.15  658.501311
# 1532363040000  7735.58  7749.00  7722.73  7729.99  287.894207
# 1532363940000  7730.49  7740.00  7723.00  7733.17  217.210836
# 1532364840000  7734.98  7745.01  7732.77  7745.00  383.939547
#
#                Quote_asset_volume  Number_of_trades  Base_asset_volume  \
# Timestamp
# 1532361240000        2.939918e+06              2292         193.695606
# 1532362140000        5.082207e+06              2913         323.362969
# 1532363040000        2.227859e+06              2367         128.856921
# 1532363940000        1.679909e+06              1968         130.330289
# 1532364840000        2.971080e+06              2262         273.541665
#
#                Taker_buy_base_asset_volume  label  ...  min_Close_change_200M  \
# Timestamp                                          ...
# 1532361240000                 1.498316e+06    0.0  ...               0.510174
# 1532362140000                 2.496556e+06    0.0  ...               0.510174
# 1532363040000                 9.972310e+05    0.0  ...               0.510174
# 1532363940000                 1.008019e+06    1.0  ...               0.510174
# 1532364840000                 2.116857e+06    1.0  ...               0.510174
#
#                max_Close_change_200M  mean_Close_change_200M  \
# Timestamp
# 1532361240000               -0.66561                0.220521
# 1532362140000               -0.66561                0.195658
# 1532363040000               -0.66561                0.200699
# 1532363940000               -0.66561                0.204524
# 1532364840000               -0.66561                0.212185
#
#                median_Close_change_200M  var_Close_change_200M  \
# Timestamp
# 1532361240000                  0.197136              -0.477396
# 1532362140000                  0.178449              -0.477494
# 1532363040000                  0.178449              -0.477514
# 1532363940000                  0.178449              -0.477522
# 1532364840000                  0.197136              -0.477541
#
#                min_Close_change_500M  max_Close_change_500M  \
# Timestamp
# 1532361240000               0.538651              -0.689578
# 1532362140000               0.538651              -0.689578
# 1532363040000               0.538651              -0.689578
# 1532363940000               0.538651              -0.689578
# 1532364840000               0.538651              -0.689578
#
#                mean_Close_change_500M  median_Close_change_500M  \
# Timestamp
# 1532361240000                0.092251                  0.203616
# 1532362140000                0.089778                  0.203616
# 1532363040000                0.087376                  0.184624
# 1532363940000                0.076064                  0.169630
# 1532364840000                0.082444                  0.184624
#
#                var_Close_change_500M
# Timestamp
# 1532361240000              -0.519414
# 1532362140000              -0.519407
# 1532363040000              -0.519408
# 1532363940000              -0.519465
# 1532364840000              -0.519477
#
# [5 rows x 230 columns]

# %% [markdown]
# ### train test split

# %%
X, y = df_feat[feat], df_feat['label']
X_train, X_valid, X_test = X[:int(df_feat.shape[0]*0.7)], X[int(df_feat.shape[0]*0.7):int(df_feat.shape[0]*0.85)], X[int(df_feat.shape[0]*0.85):]
y_train, y_valid, y_test = y[:int(df_feat.shape[0]*0.7)], y[int(df_feat.shape[0]*0.7):int(df_feat.shape[0]*0.85)], y[int(df_feat.shape[0]*0.85):]

# %% [markdown]
# ## logistic model

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression(C=0.1,random_state=1234, solver='lbfgs', max_iter=100, multi_class='auto', verbose=1)

# %%
clf.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.9s finished
# LogisticRegression(C=0.1, random_state=1234, verbose=1)

# %%
y_pred_val = clf.predict_proba(X_valid)

# %%
y_pred_val = y_pred_val[:, 1]

# %%
y_pred_val.shape
# Out:
# (19925,)

# %%
plt.hist(y_pred_val, bins=50)
# Out:
# (array([1.000e+00, 2.000e+00, 3.000e+00, 9.000e+00, 9.000e+00, 1.700e+01,
#         1.800e+01, 1.800e+01, 2.700e+01, 2.200e+01, 5.300e+01, 5.400e+01,
#         5.000e+01, 8.700e+01, 7.300e+01, 1.050e+02, 2.020e+02, 2.650e+02,
#         3.570e+02, 4.670e+02, 6.320e+02, 8.770e+02, 1.156e+03, 1.564e+03,
#         1.972e+03, 2.103e+03, 2.090e+03, 1.915e+03, 1.481e+03, 1.253e+03,
#         8.750e+02, 6.160e+02, 4.460e+02, 2.730e+02, 2.430e+02, 1.810e+02,
#         1.250e+02, 7.600e+01, 5.300e+01, 4.300e+01, 2.300e+01, 2.500e+01,
#         1.800e+01, 1.100e+01, 6.000e+00, 2.000e+00, 6.000e+00, 6.000e+00,
#         8.000e+00, 7.000e+00]),
#  array([0.00410432, 0.02400122, 0.04389812, 0.06379502, 0.08369192,
#         0.10358882, 0.12348572, 0.14338262, 0.16327953, 0.18317643,
#         0.20307333, 0.22297023, 0.24286713, 0.26276403, 0.28266093,
#         0.30255783, 0.32245473, 0.34235164, 0.36224854, 0.38214544,
#         0.40204234, 0.42193924, 0.44183614, 0.46173304, 0.48162994,
#         0.50152684, 0.52142374, 0.54132065, 0.56121755, 0.58111445,
#         0.60101135, 0.62090825, 0.64080515, 0.66070205, 0.68059895,
#         0.70049585, 0.72039276, 0.74028966, 0.76018656, 0.78008346,
#         0.79998036, 0.81987726, 0.83977416, 0.85967106, 0.87956796,
#         0.89946487, 0.91936177, 0.93925867, 0.95915557, 0.97905247,
#         0.99894937]),
#  <BarContainer object of 50 artists>)

# %%
roc_auc_score(y_test, y_pred_val)
# Out:
# 0.4963066441433068

# %%
X_train
# Out:
#                min_Volumn_5M  max_Volumn_5M  mean_Volumn_5M  median_Volumn_5M  \
# Timestamp
# 1532361240000      -0.262542      -0.532149       -0.420170         -0.320496
# 1532362140000      -0.262542      -0.532149       -0.418331         -0.310469
# 1532363040000      -0.262542      -0.295167       -0.301327         -0.259649
# 1532363940000      -0.231259      -0.295167       -0.297814         -0.259649
# 1532364840000      -0.462568      -0.295167       -0.372668         -0.310469
# ...                      ...            ...             ...               ...
# 1616040540000      -0.057908      -0.422041       -0.260352         -0.192385
# 1616041440000      -0.057908      -0.364422       -0.196143         -0.011512
# 1616042340000      -0.057908      -0.364422       -0.249595         -0.192385
# 1616043240000      -0.057908      -0.364422       -0.252633         -0.192385
# 1616044140000       0.089273      -0.364422       -0.214967         -0.183615
#
#                var_Volumn_5M  min_Volumn_10M  max_Volumn_10M  mean_Volumn_10M  \
# Timestamp
# 1532361240000      -0.204889       -0.366212       -0.660573        -0.528326
# 1532362140000      -0.204849       -0.366212       -0.660573        -0.498647
# 1532363040000      -0.184937       -0.366212       -0.464497        -0.435410
# 1532363940000      -0.185792       -0.366212       -0.464497        -0.453974
# 1532364840000      -0.174465       -0.366212       -0.464497        -0.473101
# ...                      ...             ...             ...              ...
# 1616040540000      -0.200862        0.176525       -0.517629        -0.241617
# 1616041440000      -0.197314        0.176525       -0.521798        -0.242635
# 1616042340000      -0.196179        0.176525       -0.521798        -0.250987
# 1616043240000      -0.196528        0.176525       -0.521798        -0.261329
# 1616044140000      -0.201112        0.176525       -0.521798        -0.258553
#
#                median_Volumn_10M  min_Volumn_60M  ...  min_Close_change_200M  \
# Timestamp                                         ...
# 1532361240000          -0.396643       -0.763189  ...               0.510174
# 1532362140000          -0.355539       -0.763189  ...               0.510174
# 1532363040000          -0.313981       -0.763189  ...               0.510174
# 1532363940000          -0.360916       -0.763189  ...               0.510174
# 1532364840000          -0.360916       -0.763189  ...               0.510174
# ...                          ...             ...  ...                    ...
# 1616040540000          -0.157319        1.071792  ...              -0.535296
# 1616041440000          -0.157319        1.071792  ...              -0.535296
# 1616042340000          -0.157319        1.071792  ...              -0.535296
# 1616043240000          -0.157319        1.071792  ...              -0.535296
# 1616044140000          -0.152175        1.071792  ...              -0.535296
#
#                max_Close_change_200M  mean_Close_change_200M  \
# Timestamp
# 1532361240000              -0.665610                0.220521
# 1532362140000              -0.665610                0.195658
# 1532363040000              -0.665610                0.200699
# 1532363940000              -0.665610                0.204524
# 1532364840000              -0.665610                0.212185
# ...                              ...                     ...
# 1616040540000               1.135155                2.968918
# 1616041440000               1.135155                2.869000
# 1616042340000               1.135155                2.725677
# 1616043240000               1.135155                2.779240
# 1616044140000               1.135155                2.835602
#
#                median_Close_change_200M  var_Close_change_200M  \
# Timestamp
# 1532361240000                  0.197136              -0.477396
# 1532362140000                  0.178449              -0.477494
# 1532363040000                  0.178449              -0.477514
# 1532363940000                  0.178449              -0.477522
# 1532364840000                  0.197136              -0.477541
# ...                                 ...                    ...
# 1616040540000                  2.279037               1.545293
# 1616041440000                  2.279037               1.537427
# 1616042340000                  2.119157               1.540760
# 1616043240000                  2.119157               1.536877
# 1616044140000                  2.279037               1.537722
#
#                min_Close_change_500M  max_Close_change_500M  \
# Timestamp
# 1532361240000               0.538651              -0.689578
# 1532362140000               0.538651              -0.689578
# 1532363040000               0.538651              -0.689578
# 1532363940000               0.538651              -0.689578
# 1532364840000               0.538651              -0.689578
# ...                              ...                    ...
# 1616040540000              -1.855149               2.420953
# 1616041440000              -1.855149               2.420953
# 1616042340000              -1.855149               2.420953
# 1616043240000              -1.855149               2.420953
# 1616044140000              -1.855149               2.420953
#
#                mean_Close_change_500M  median_Close_change_500M  \
# Timestamp
# 1532361240000                0.092251                  0.203616
# 1532362140000                0.089778                  0.203616
# 1532363040000                0.087376                  0.184624
# 1532363940000                0.076064                  0.169630
# 1532364840000                0.082444                  0.184624
# ...                               ...                       ...
# 1616040540000                0.631130                  2.345679
# 1616041440000                0.609773                  2.345679
# 1616042340000                0.548305                  2.188748
# 1616043240000                0.575195                  2.188748
# 1616044140000                0.818135                  2.345679
#
#                var_Close_change_500M
# Timestamp
# 1532361240000              -0.519414
# 1532362140000              -0.519407
# 1532363040000              -0.519408
# 1532363940000              -0.519465
# 1532364840000              -0.519477
# ...                              ...
# 1616040540000               1.945791
# 1616041440000               1.944888
# 1616042340000               1.946279
# 1616043240000               1.945215
# 1616044140000               1.927405
#
# [92982 rows x 216 columns]

# %%
from lightgbm import LGBMClassifier
model = LGBMClassifier()

# %%
X, y = df_feat[feat], df_feat['Close_change']
X_train, X_valid, X_test = X[:int(df_feat.shape[0]*0.7)], X[int(df_feat.shape[0]*0.7):int(df_feat.shape[0]*0.85)], X[int(df_feat.shape[0]*0.85):]
y_train, y_valid, y_test = y[:int(df_feat.shape[0]*0.7)], y[int(df_feat.shape[0]*0.7):int(df_feat.shape[0]*0.85)], y[int(df_feat.shape[0]*0.85):]

# %%
params = {'objective': 'regression_l1',
            'metric': ['rmse', 'mape'],
            'is_unbalance':True,
            'boosting':'gbdt',
            'num_boost_round':1000,
            'early_stopping_rounds':10,
            'learning_rate': 0.1,
            'max_depth': -1,
            'num_leaves': 64,
            'feature_fraction': 0.8,
#           'bagging_fraction': 0.8,
#           'min_data_in_leaf': 10,
            'verbosity': 1}

# %%
import lightgbm as lgb
train_data = lgb.Dataset(X_train, y_train)
valid_data = lgb.Dataset(X_valid, y_valid, reference=train_data)

# %%
model = lgb.train(params, train_data,                     
                  valid_sets=[train_data, valid_data],
                  valid_names=['train', 'valid'])
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.090988 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 54992
# [LightGBM] [Info] Number of data points in the train set: 92982, number of used features: 216
# [LightGBM] [Info] Start training from score 0.190000
# [1]	train's rmse: 80.4761	train's mape: 0.964921	valid's rmse: 203.909	valid's mape: 0.996697
# Training until validation scores don't improve for 10 rounds
# [2]	train's rmse: 80.4488	train's mape: 0.963823	valid's rmse: 203.907	valid's mape: 0.997883
# [3]	train's rmse: 80.4256	train's mape: 0.963576	valid's rmse: 203.89	valid's mape: 0.999304
# [4]	train's rmse: 80.3949	train's mape: 0.964112	valid's rmse: 203.892	valid's mape: 1.00042
# [5]	train's rmse: 80.3596	train's mape: 0.964376	valid's rmse: 203.895	valid's mape: 1.00276
# [6]	train's rmse: 80.3294	train's mape: 0.965123	valid's rmse: 203.901	valid's mape: 1.00556
# [7]	train's rmse: 80.3195	train's mape: 0.965615	valid's rmse: 203.902	valid's mape: 1.00796
# [8]	train's rmse: 80.2652	train's mape: 0.965537	valid's rmse: 203.89	valid's mape: 1.01098
# [9]	train's rmse: 80.2436	train's mape: 0.966343	valid's rmse: 203.893	valid's mape: 1.01313
# [10]	train's rmse: 80.1541	train's mape: 0.966765	valid's rmse: 203.932	valid's mape: 1.01825
# [11]	train's rmse: 80.1466	train's mape: 0.967202	valid's rmse: 203.934	valid's mape: 1.02047
# Early stopping, best iteration is:
# [1]	train's rmse: 80.4761	train's mape: 0.964921	valid's rmse: 203.909	valid's mape: 0.996697

# %%
importance_df = (
    pd.DataFrame({
        'feature_name': model.feature_name(),
        'importance_gain': model.feature_importance(importance_type='gain'),
        'importance_split': model.feature_importance(importance_type='split'),
    })
    .sort_values('importance_gain', ascending=False)
    .reset_index(drop=True)
)
importance_df.head(50)
# Out:
#                            feature_name  importance_gain  importance_split
# 0                  mean_Close_change_5M       460.069399                 5
# 1                    min_High_change_5M        79.265400                 3
# 2                 mean_Close_change_10M        59.770199                 2
# 3                    max_High_change_5M        53.770401                 1
# 4                   mean_Low_change_10M        35.959200                 2
# 5                    mean_Low_change_5M        32.431000                 2
# 6                   mean_Low_change_60M        30.579101                 2
# 7            mean_Base_asset_volume_10M        29.900000                 2
# 8   min_Taker_buy_base_asset_volume_60M        29.417201                 2
# 9                 median_Low_change_10M        28.947801                 2
# 10                  max_Close_change_5M        27.356001                 1
# 11   var_Taker_buy_base_asset_volume_5M        26.628201                 1
# 12                 median_Low_change_5M        25.147900                 2
# 13             var_Base_asset_volume_5M        22.789700                 1
# 14                 mean_Open_change_60M        22.563299                 1
# 15             median_Close_change_500M        20.957701                 1
# 16                  var_Close_change_5M        19.083500                 1
# 17                   var_High_change_5M        17.606199                 1
# 18                  max_Low_change_500M        17.416000                 1
# 19            min_Base_asset_volume_10M        17.342899                 1
# 20                  mean_Open_change_5M        16.751400                 1
# 21   max_Taker_buy_base_asset_volume_5M        16.313101                 1
# 22       median_Quote_asset_volume_200M        15.921900                 1
# 23                mean_Open_change_200M        15.444500                 1
# 24                       max_Volumn_60M        15.375400                 1
# 25  max_Taker_buy_base_asset_volume_60M        15.335300                 1
# 26                      min_Volumn_200M        14.836500                 1
# 27                       min_Volumn_60M        14.486800                 1
# 28                   max_Open_change_5M        14.451700                 1
# 29                    min_Low_change_5M        14.372700                 1
# 30               median_Low_change_200M        14.259100                 1
# 31                    var_Low_change_5M        14.161200                 1
# 32            var_Base_asset_volume_60M        13.826900                 1
# 33                min_Close_change_500M        13.811700                 1
# 34              median_High_change_200M        13.740200                 1
# 35                  max_High_change_10M        13.503300                 1
# 36                      max_Volumn_200M        13.450000                 1
# 37                 mean_Open_change_10M        13.326600                 1
# 38                  var_Low_change_200M        13.158100                 1
# 39                 max_High_change_500M        13.078000                 1
# 40                  min_High_change_60M        12.976000                 1
# 41          median_Number_of_trades_60M        12.958500                 1
# 42                 min_Close_change_60M        12.948900                 1
# 43                mean_Open_change_500M        12.928600                 1
# 44               median_Open_change_60M        12.635700                 1
# 45         mean_Quote_asset_volume_200M        12.510800                 1
# 46        median_Base_asset_volume_200M        12.279500                 1
# 47         median_Number_of_trades_500M        12.224000                 1
# 48              median_Open_change_500M        12.114000                 1
# 49                 max_Open_change_200M         0.000000                 0

# %%
pred = model.predict(X_test)
#y_pred = [round(x) for x in pred]

# %%
pred
# Out:
# array([ 0.464 ,  0.1665,  0.123 , ...,  0.186 ,  0.123 , -0.0515])

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 print(classification_report(y_test, pred))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:2110, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    1998 def classification_report(
#    1999     y_true,
#    2000     y_pred,
#    (...)
#    2007     zero_division="warn",
#    2008 ):
#    2009     """Build a text report showing the main classification metrics.
#    2010
#    2011     Read more in the :ref:`User Guide <classification_report>`.
#    (...)
#    2107     <BLANKLINE>
#    2108     """
# -> 2110     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2112     if labels is None:
#    2113         labels = unique_labels(y_true, y_pred)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:104, in _check_targets(y_true, y_pred)
#     102 # No metrics support "multiclass-multioutput" format
#     103 if y_type not in ["binary", "multiclass", "multilabel-indicator"]:
# --> 104     raise ValueError("{0} is not supported".format(y_type))
#     106 if y_type in ["binary", "multiclass"]:
#     107     y_true = column_or_1d(y_true)
#
# ValueError: continuous is not supported

# %%
plt.hist(model.predict(X_test), bins=20)
# Out:
# (array([7.100e+01, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 2.500e+01,
#         2.130e+02, 6.300e+01, 2.000e+00, 3.903e+03, 2.948e+03, 5.635e+03,
#         4.605e+03, 9.360e+02, 7.280e+02, 5.720e+02, 1.560e+02, 6.700e+01,
#         0.000e+00, 1.000e+00]),
#  array([-1.76900006, -1.59327506, -1.41755005, -1.24182505, -1.06610005,
#         -0.89037505, -0.71465005, -0.53892504, -0.36320004, -0.18747504,
#         -0.01175004,  0.16397497,  0.33969997,  0.51542497,  0.69114997,
#          0.86687497,  1.04259998,  1.21832498,  1.39404998,  1.56977498,
#          1.74549999]),
#  <BarContainer object of 20 artists>)

# %%
roc_auc_score(y_test, pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [65], in <cell line: 1>()
# ----> 1 roc_auc_score(y_test, pred)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_ranking.py:575, in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     567     return _average_binary_score(
#     568         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     569         y_true,
#    (...)
#     572         sample_weight=sample_weight,
#     573     )
#     574 else:  # multilabel-indicator
# --> 575     return _average_binary_score(
#     576         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     577         y_true,
#     578         y_score,
#     579         average,
#     580         sample_weight=sample_weight,
#     581     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_base.py:72, in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      70 y_type = type_of_target(y_true)
#      71 if y_type not in ("binary", "multilabel-indicator"):
# ---> 72     raise ValueError("{0} format is not supported".format(y_type))
#      74 if y_type == "binary":
#      75     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#
# ValueError: continuous format is not supported

# %% [markdown]
# ## arima

# %%
import gc
gc.collect()
# Out:
# 0

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
from pmdarima import auto_arima
model = ARIMA(
    df_feat['Close_change'],
    order = (4, 1, 2),
    exog=df_feat[feat])
# Out:
# C:\Users\Nguyen The Minh Duc\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Nguyen The Minh Duc\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Nguyen The Minh Duc\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
model_fit = model.fit()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [71], in <cell line: 1>()
# ----> 1 model_fit = model.fit()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\arima\model.py:390, in ARIMA.fit(self, start_params, transformed, includes_fixed, method, method_kwargs, gls, gls_kwargs, cov_type, cov_kwds, return_params, low_memory)
#     387 else:
#     388     method_kwargs.setdefault('disp', 0)
# --> 390     res = super().fit(
#     391         return_params=return_params, low_memory=low_memory,
#     392         cov_type=cov_type, cov_kwds=cov_kwds, **method_kwargs)
#     393     if not return_params:
#     394         res.fit_details = res.mlefit
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:704, in MLEModel.fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     702         flags['hessian_method'] = optim_hessian
#     703     fargs = (flags,)
# --> 704     mlefit = super(MLEModel, self).fit(start_params, method=method,
#     705                                        fargs=fargs,
#     706                                        maxiter=maxiter,
#     707                                        full_output=full_output,
#     708                                        disp=disp, callback=callback,
#     709                                        skip_hessian=True, **kwargs)
#     711 # Just return the fitted parameters if requested
#     712 if return_params:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\base\model.py:563, in LikelihoodModel.fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     560     del kwargs["use_t"]
#     562 optimizer = Optimizer()
# --> 563 xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     564                                                fargs, kwargs,
#     565                                                hessian=hess,
#     566                                                method=method,
#     567                                                disp=disp,
#     568                                                maxiter=maxiter,
#     569                                                callback=callback,
#     570                                                retall=retall,
#     571                                                full_output=full_output)
#     572 # Restore cov_type, cov_kwds and use_t
#     573 optim_settings.update(kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\base\optimizer.py:241, in Optimizer._fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     238     fit_funcs.update(extra_fit_funcs)
#     240 func = fit_funcs[method]
# --> 241 xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     242                      disp=disp, maxiter=maxiter, callback=callback,
#     243                      retall=retall, full_output=full_output,
#     244                      hess=hessian)
#     246 optim_settings = {'optimizer': method, 'start_params': start_params,
#     247                   'maxiter': maxiter, 'full_output': full_output,
#     248                   'disp': disp, 'fargs': fargs, 'callback': callback,
#     249                   'retall': retall, "extra_fit_funcs": extra_fit_funcs}
#     250 optim_settings.update(kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\base\optimizer.py:651, in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     648 elif approx_grad:
#     649     func = f
# --> 651 retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     652                                  callback=callback, args=fargs,
#     653                                  bounds=bounds, disp=disp,
#     654                                  **extra_kwargs)
#     656 if full_output:
#     657     xopt, fopt, d = retvals
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_lbfgsb_py.py:199, in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     187     disp = iprint
#     188 opts = {'disp': disp,
#     189         'iprint': iprint,
#     190         'maxcor': m,
#    (...)
#     196         'callback': callback,
#     197         'maxls': maxls}
# --> 199 res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     200                        **opts)
#     201 d = {'grad': res['jac'],
#     202      'task': res['message'],
#     203      'funcalls': res['nfev'],
#     204      'nit': res['nit'],
#     205      'warnflag': res['status']}
#     206 f = res['fun']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_lbfgsb_py.py:362, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     356 task_str = task.tobytes()
#     357 if task_str.startswith(b'FG'):
#     358     # The minimization routine wants f and g at the current x.
#     359     # Note that interruptions due to maxfun are postponed
#     360     # until the completion of the current minimization iteration.
#     361     # Overwrite f and g:
# --> 362     f, g = func_and_grad(x)
#     363 elif task_str.startswith(b'NEW_X'):
#     364     # new iteration
#     365     n_iterations += 1
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_differentiable_functions.py:286, in ScalarFunction.fun_and_grad(self, x)
#     284     self._update_x_impl(x)
#     285 self._update_fun()
# --> 286 self._update_grad()
#     287 return self.f, self.g
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_differentiable_functions.py:256, in ScalarFunction._update_grad(self)
#     254 def _update_grad(self):
#     255     if not self.g_updated:
# --> 256         self._update_grad_impl()
#     257         self.g_updated = True
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_differentiable_functions.py:173, in ScalarFunction.__init__.<locals>.update_grad()
#     171 self._update_fun()
#     172 self.ngev += 1
# --> 173 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     174                            **finite_diff_options)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_numdiff.py:505, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     502     use_one_sided = False
#     504 if sparsity is None:
# --> 505     return _dense_difference(fun_wrapped, x0, f0, h,
#     506                              use_one_sided, method)
#     507 else:
#     508     if not issparse(sparsity) and len(sparsity) == 2:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_numdiff.py:576, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     574     x = x0 + h_vecs[i]
#     575     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 576     df = fun(x) - f0
#     577 elif method == '3-point' and use_one_sided[i]:
#     578     x1 = x0 + h_vecs[i]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_numdiff.py:456, in approx_derivative.<locals>.fun_wrapped(x)
#     455 def fun_wrapped(x):
# --> 456     f = np.atleast_1d(fun(x, *args, **kwargs))
#     457     if f.ndim > 1:
#     458         raise RuntimeError("`fun` return value has "
#     459                            "more than 1 dimension.")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\base\model.py:531, in LikelihoodModel.fit.<locals>.f(params, *args)
#     530 def f(params, *args):
# --> 531     return -self.loglike(params, *args) / nobs
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:939, in MLEModel.loglike(self, params, *args, **kwargs)
#     936 if complex_step:
#     937     kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
# --> 939 loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     941 # Koopman, Shephard, and Doornik recommend maximizing the average
#     942 # likelihood to avoid scale issues, but the averaging is done
#     943 # automatically in the base model `fit` method
#     944 return loglike
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py:983, in KalmanFilter.loglike(self, **kwargs)
#     967 r"""
#     968 Calculate the loglikelihood associated with the statespace model.
#     969
#    (...)
#     979     The joint loglikelihood.
#     980 """
#     981 kwargs.setdefault('conserve_memory',
#     982                   MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD)
# --> 983 kfilter = self._filter(**kwargs)
#     984 loglikelihood_burn = kwargs.get('loglikelihood_burn',
#     985                                 self.loglikelihood_burn)
#     986 if not (kwargs['conserve_memory'] & MEMORY_NO_LIKELIHOOD):
#
# KeyboardInterrupt:

# %%
print(model_fit.summary())

# %%
forecast = model_fit.predict()

# %%
(forecast * df_feat['Close_change'] > 0).sum()/len(forecast)
