# %% [markdown]
# ### Import library

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from label import label
import seaborn as sns
import plotly.graph_objs as go
import plotly.offline as py
# %matplotlib inline

# %% [markdown]
# # Read data

# %%
df = label('D:\\Project\\Bitcoin_Price_Prediction\\data\\binance-BTCUSDT-1m.csv', t=15)

# %%
df.head()
# Out:
#                   Open     High      Low    Close      Volumn  Timestamp End  \
# Timestamp
# 1531910340000  7370.00  7404.23  7365.10  7402.13  421.446875  1531911239999
# 1531911240000  7404.23  7419.09  7393.03  7398.00  400.220193  1531912139999
# 1531912140000  7397.00  7413.67  7388.97  7401.99  283.424582  1531913039999
# 1531913040000  7401.99  7433.32  7395.00  7430.33  385.377189  1531913939999
# 1531913940000  7430.33  7433.58  7408.07  7418.00  412.557017  1531914839999
#
#                Quote_asset_volume  Number_of_trades  Base_asset_volume  \
# Timestamp
# 1531910340000        3.112218e+06              2210         244.531743
# 1531911240000        2.963666e+06              2825         217.698269
# 1531912140000        2.097944e+06              2022         158.367674
# 1531913040000        2.858399e+06              2194         230.656692
# 1531913940000        3.061536e+06              2352         231.403556
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 133333 entries, 1531910340000 to 1651909140000
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Open                         133333 non-null  float64
#  1   High                         133333 non-null  float64
#  2   Low                          133333 non-null  float64
#  3   Close                        133333 non-null  float64
#  4   Volumn                       133333 non-null  float64
#  5   Timestamp End                133333 non-null  int64
#  6   Quote_asset_volume           133333 non-null  float64
#  7   Number_of_trades             133333 non-null  int64
#  8   Base_asset_volume            133333 non-null  float64
#  9   Taker_buy_base_asset_volume  133333 non-null  float64
#  10  Time_UTC_Start               133333 non-null  object
#  11  label                        133333 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Open           High            Low          Close  \
# count  133333.000000  133333.000000  133333.000000  133333.000000
# mean    21754.936998   21814.715983   21693.236569   21755.148528
# std     18812.816085   18867.142710   18757.397595   18812.824664
# min      3161.570000    3176.240000    3156.260000    3162.070000
# 25%      7286.660000    7303.540000    7270.040000    7286.610000
# 50%     10332.960000   10352.000000   10312.500000   10332.970000
# 75%     39323.880000   39450.000000   39195.020000   39323.740000
# max     68640.000000   69000.000000   68505.880000   68640.000000
#
#               Volumn  Timestamp End  Quote_asset_volume  Number_of_trades  \
# count  133333.000000   1.333330e+05        1.333330e+05     133333.000000
# mean      592.002858   1.591911e+12        1.375199e+07       9715.141975
# std       657.280341   3.464110e+10        2.107931e+07      10677.664602
# min         0.000000   1.531911e+12        0.000000e+00          0.000000
# ...

# %%
del df['Timestamp End'], df['Time_UTC_Start']

# %%
df.index = pd.to_datetime(df.index)

# %%
#df.head()

# %% [markdown]
# ## Plot data base on the Close column

# %%
close_price = go.Scatter(x=df.index, y=df['Close'], name= 'Price')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 plt.plot(close_price)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
# ...
