# %%
import pandas as pd
import numpy as np 

df = pd.read_csv("../../data/raw_data_binance_BTC_USDT_1h.csv")

# %%
df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df
# Out:
#                  time_open      open      high       low     close  \
# 0      2017-12-19 15:00:00  18569.52  18650.02  18545.11  18620.01
# 1      2017-12-19 16:00:00  18620.02  18695.20  18165.99  18234.89
# 2      2017-12-19 17:00:00  18259.40  18259.40  16300.00  16852.00
# 3      2017-12-19 18:00:00  16890.00  17800.00  16550.22  17250.00
# 4      2017-12-19 19:00:00  17214.20  17900.00  17100.00  17550.50
# ...                    ...       ...       ...       ...       ...
# 39376  2022-06-22 06:00:00  20897.00  20943.17  20551.00  20723.52
# 39377  2022-06-22 07:00:00  20723.51  20736.68  20421.38  20587.01
# 39378  2022-06-22 08:00:00  20587.01  20719.21  20388.01  20411.24
# 39379  2022-06-22 09:00:00  20411.23  20526.67  20330.00  20466.47
# 39380  2022-06-22 10:00:00  20466.47  20567.60  20253.96  20317.88
#
#             volume  quote_asset_volume  number_of_trades  \
# 0       338.319586        6.292816e+06            2568.0
# 1       505.051461        9.298289e+06            4418.0
# 2      1831.436840        3.155096e+07           15372.0
# 3      1226.949207        2.113936e+07           11082.0
# 4       823.862800        1.443043e+07            6158.0
# ...            ...                 ...               ...
# 39376  2613.774410        5.412753e+07           42193.0
# 39377  4195.854000        8.638902e+07           58827.0
# 39378  3271.915890        6.732365e+07           53095.0
# 39379  3588.324010        7.332763e+07           53154.0
# 39380  2923.225220        5.969947e+07           45920.0
#
#        taker_buy_base_asset_volume  taker_buy_quote_asset_volume  ...  \
# 0                       128.750204                  2.395303e+06  ...
# 1                       198.079068                  3.645787e+06  ...
# 2                       827.913384                  1.426553e+07  ...
# 3                       612.086815                  1.057065e+07  ...
# 4                       396.400387                  6.944349e+06  ...
# ...                            ...                           ...  ...
# 39376                  1245.791750                  2.580072e+07  ...
# 39377                  1911.811000                  3.937325e+07  ...
# 39378                  1526.045120                  3.140632e+07  ...
# 39379                  1650.636910                  3.372889e+07  ...
# 39380                  1263.597380                  2.580499e+07  ...
#
#        exchange_inflow  exchange_outflow  exchange_in_house_flow  \
# 0           438.756474        646.062603              401.660211
# 1           684.389122        478.744220              413.444266
# 2           453.595961       1297.391094              353.530010
# 3           419.317822        903.013592              340.513670
# 4           766.721481        615.788112              328.555678
# ...                ...               ...                     ...
# 39376       153.565471        119.542916              387.697743
# 39377       124.500929        150.375813              171.623315
# 39378       398.469901        335.757526              643.637576
# 39379       269.312576        389.095246              491.761055
# 39380       359.546457        838.413796              305.829424
#
#        exchange_whale_ratio  exchange_supply_ratio  miner_reserve  \
# 0                  0.301078               0.003826   1.898231e+06
# 1                  0.451029               0.003838   1.898321e+06
# 2                  0.274447               0.003787   1.898360e+06
# 3                  0.300153               0.003759   1.898343e+06
# 4                  0.221535               0.003768   1.898571e+06
# ...                     ...                    ...            ...
# 39376              0.781393               0.026375   1.863004e+06
# 39377              0.945063               0.026373   1.863009e+06
# 39378              0.789813               0.026376   1.863055e+06
# 39379              0.849073               0.026370   1.863106e+06
# 39380              0.779607               0.026345   1.863022e+06
#
#        miner_reserve_USD  miner_outflow  miner_inflow  coinbase_premium_index
# 0           3.548095e+10     298.597899    130.811876                1.503275
# 1           3.515585e+10      43.278379    132.843798                2.325706
# 2           3.378443e+10     153.771005    192.685012                8.592452
# 3           3.334911e+10     175.623064    158.962416                3.513043
# 4           3.384452e+10     188.845163    416.871321                3.580981
# ...                  ...            ...           ...                     ...
# 39376       3.856502e+10       0.271680     13.029678               -0.128164
# 39377       3.830506e+10       7.642881     12.755513               -0.109535
# 39378       3.798884e+10       1.741578     47.969704               -0.095144
# 39379       3.808702e+10      83.101458    133.700908               -0.111402
# 39380       3.780682e+10     424.782719    341.570021               -0.137514
#
# [39381 rows x 22 columns]

# %%
from talipp.ohlcv import OHLCVFactory
from talipp.indicators import AccuDist, ADX, ALMA, AO, Aroon, ATR, BB, BOP, CCI, ChaikinOsc, ChandeKrollStop, CHOP, CoppockCurve, DEMA, DonchianChannels, DPO, EMA, EMV, ForceIndex, HMA, \
    Ichimoku, KAMA, KeltnerChannels, KST, KVO, MACD, MassIndex, MeanDev, OBV, PivotsHL, ROC, RSI, ParabolicSAR, SFX, SMA, SMMA, SOBV, \
    StdDev, Stoch, StochRSI, SuperTrend, TEMA, TRIX, TSI, UO, VTX, VWAP, VWMA, WMA

price_types = ["open", "close", "high", "low"]
periods = [2,4,8,12,24,48,96,192]

close = df["open"].to_numpy()
high =  df["high"].to_numpy()
low = df["low"].to_numpy()
volume = df["volume"].to_numpy()
open = df["open"].to_numpy()

ohlcv = OHLCVFactory.from_matrix2([
    df["open"].to_numpy(),
    df["high"].to_numpy(),
    df["low"].to_numpy(),
    df["close"].to_numpy(),
    df["volume"].to_numpy()]
)

dct = {
    'close': close,
    'high': high,
    'low': low,
    'open': open,
    'volume': volume
}

def shift(df, col_name):
    df[col_name] = df[col_name].shift(df[col_name].isna().sum())

# %%
df["CoppockCurve"] = pd.Series(CoppockCurve(11, 14, 10, close))
df["CoppockCurve"] = df["CoppockCurve"].shift(df["CoppockCurve"].isna().sum())

df["KAMA"] = pd.Series(KAMA(14, 2, 30, close))
df["KAMA"] = df["KAMA"].shift(df["KAMA"].isna().sum())

kst_series = pd.Series(KST(10, 10, 15, 10, 20, 10, 30, 15, 9, close))
df["KST_kst"] = pd.Series(np.vectorize(lambda x: x.kst)(kst_series))
df["KST_signal"] = pd.Series(np.vectorize(lambda x: x.signal)(kst_series))
df["KST_kst"] = df["KST_kst"].shift(df["KST_kst"].isna().sum())
df["KST_signal"] = df["KST_signal"].shift(df["KST_signal"].isna().sum())

macd_series = pd.Series(MACD(12, 26, 9, close))
df["MACD_macd"] = pd.Series(np.vectorize(lambda x: x.macd)(macd_series))
df["MACD_signal"] = pd.Series(np.vectorize(lambda x: x.signal)(macd_series))
df["MACD_macd"] = df["MACD_macd"].shift(df["MACD_macd"].isna().sum())
df["MACD_signal"] = df["MACD_signal"].shift(df["MACD_signal"].isna().sum())

df["MassIndex"] = pd.Series(MassIndex(9, 9, 10, ohlcv))
df["MassIndex"] = df["MassIndex"].shift(df["MassIndex"].isna().sum())

df["OBV"] = pd.Series(OBV(ohlcv))
df["OBV"] = df["OBV"].shift(df["OBV"].isna().sum())

df["KVO"] = pd.Series(KVO(34, 55, ohlcv))
df["KVO"] = df["KVO"].shift(df["KVO"].isna().sum())

df["VWAP"] = pd.Series(VWAP(ohlcv))
df["VWAP"] = df["VWAP"].shift(df["VWAP"].isna().sum())

df["AccuDist"] = pd.Series(AccuDist(ohlcv))
df["AccuDist"] = df["AccuDist"].shift(df["AccuDist"].isna().sum())

df["BOP"] = pd.Series(BOP(ohlcv))
df["BOP"] = df["BOP"].shift(df["BOP"].isna().sum())

df["UO"] = pd.Series(UO(7, 14, 28, ohlcv))
df["UO"] = df["UO"].shift(df["UO"].isna().sum())

df["TSI"] = pd.Series(TSI(13, 25, close))
df["TSI"] = df["TSI"].shift(df["TSI"].isna().sum())

df["AO"] = pd.Series(AO(5, 34, ohlcv))
df["AO"] = df["AO"].shift(df["AO"].isna().sum())

for period in periods:
    df["CCI"+str(period)] = pd.Series(CCI(period, ohlcv))
    shift(df, "CCI"+str(period))    

    df["CHOP"+str(period)] = pd.Series(CHOP(period, ohlcv))
    shift(df, "CHOP"+str(period))    

    vtx_series = pd.Series(VTX(period, ohlcv))
    df["VTX"+str(period)+"_plus_vtx"] = pd.Series(np.vectorize(lambda x: x.plus_vtx)(vtx_series))
    df["VTX"+str(period)+"_minus_vtx"] = pd.Series(np.vectorize(lambda x: x.minus_vtx)(vtx_series))
    df["VTX"+str(period)+"_plus_vtx"] = df["VTX"+str(period)+"_plus_vtx"].shift(df["VTX"+str(period)+"_plus_vtx"].isna().sum())
    df["VTX"+str(period)+"_minus_vtx"] = df["VTX"+str(period)+"_minus_vtx"].shift(df["VTX"+str(period)+"_minus_vtx"].isna().sum()) 

    df["SOBV"+str(period)] = pd.Series(SOBV(period, ohlcv))
    shift(df, "SOBV"+str(period))  
    
    df["ATR"+str(period)] = pd.Series(ATR(period, ohlcv))
    shift(df, "ATR"+str(period))  

    df["ForceIndex"+str(period)] = pd.Series(ForceIndex(period, ohlcv))
    shift(df, "ForceIndex"+str(period)) 
    
    adx_series = pd.Series(ADX(period, period, ohlcv))
    df["ADX_plus_di"] = pd.Series(np.vectorize(lambda x: x.plus_di)(adx_series))
    df["ADX_minus_di"] = pd.Series(np.vectorize(lambda x: x.minus_di)(adx_series))
    df["ADX_adx"] = pd.Series(np.vectorize(lambda x: x.adx)(adx_series))
    df["ADX_plus_di"] = df["ADX_plus_di"].shift(df["ADX_plus_di"].isna().sum())
    df["ADX_minus_di"] = df["ADX_minus_di"].shift(df["ADX_minus_di"].isna().sum())
    df["ADX_adx"] = df["ADX_adx"].shift(df["ADX_adx"].isna().sum())

    
    df["ForceIndex"+str(period)] = pd.Series(ForceIndex(period, ohlcv))
    shift(df, "ForceIndex"+str(period)) 
    
    for price_type in price_types:
        df[price_type+"_max"+str(period)] = df[price_type].rolling(period).max()
        
        df[price_type+"_min"+str(period)] = df[price_type].rolling(period).min()
        
        df[price_type+"_median"+str(period)] = df[price_type].rolling(period).median()
        
        if period >= 12:
            df[price_type+"_quantile25_"+str(period)] = df[price_type].rolling(period).quantile(0.25)
            df[price_type+"_quantile75_"+str(period)] = df[price_type].rolling(period).quantile(0.75)
        
        df[price_type+"_SMA"+str(period)] = pd.Series(SMA(period, dct[price_type]))
        shift(df, price_type+"_SMA"+str(period))

        df[price_type+"_SMMA"+str(period)] = pd.Series(SMMA(period, dct[price_type]))
        shift(df, price_type+"_SMMA"+str(period))

        df[price_type+"_WMA"+str(period)] = pd.Series(WMA(period, dct[price_type]))
        shift(df, price_type+"_WMA"+str(period))

        df[price_type+"_ALMA"+str(period)] = pd.Series(ALMA(period, 0.85, 6, dct[price_type]))
        shift(df, price_type+"_ALMA"+str(period))   

        df[price_type+"_TEMA"+str(period)] = pd.Series(TEMA(period, dct[price_type]))
        shift(df, price_type+"_TEMA"+str(period))   

        df[price_type+"_EMA"+str(period)] = pd.Series(EMA(period, dct[price_type]))
        shift(df, price_type+"_EMA"+str(period)) 

        df[price_type+"_DEMA"+str(period)] = pd.Series(DEMA(period, dct[price_type]))
        shift(df, price_type+"_DEMA"+str(period))  

        df[price_type+"_DPO"+str(period)] = pd.Series(DPO(period, dct[price_type]))
        shift(df, price_type+"_DPO"+str(period)) 

        df[price_type+"_HMA"+str(period)] = pd.Series(HMA(period, dct[price_type]))
        shift(df, price_type+"_HMA"+str(period))

        df[price_type+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, dct[price_type]))
        shift(df, price_type+"_MeanDev"+str(period))  
        
        df[price_type+"_StdDev"+str(period)] = pd.Series(StdDev(period, dct[price_type]))
        shift(df, price_type+"_StdDev"+str(period))  

        df[price_type+"_RSI"+str(period)] = pd.Series(RSI(period, dct[price_type]))
        shift(df, price_type+"_RSI"+str(period))

        df[price_type+"_ROC"+str(period)] = pd.Series(ROC(period, dct[price_type]))
        shift(df, price_type+"_ROC"+str(period))
        
        df[price_type+"_TRIX"+str(period)] = pd.Series(TRIX(period, dct[price_type]))
        shift(df, price_type+"_TRIX"+str(period))
# Out:
# /tmp/ipykernel_33334/1214833122.py:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["ATR"+str(period)] = pd.Series(ATR(period, ohlcv))
# /tmp/ipykernel_33334/1214833122.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["ForceIndex"+str(period)] = pd.Series(ForceIndex(period, ohlcv))
# /tmp/ipykernel_33334/1214833122.py:81: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_max"+str(period)] = df[price_type].rolling(period).max()
# /tmp/ipykernel_33334/1214833122.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_min"+str(period)] = df[price_type].rolling(period).min()
# /tmp/ipykernel_33334/1214833122.py:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_median"+str(period)] = df[price_type].rolling(period).median()
# /tmp/ipykernel_33334/1214833122.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_SMA"+str(period)] = pd.Series(SMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:94: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_SMMA"+str(period)] = pd.Series(SMMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_WMA"+str(period)] = pd.Series(WMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:100: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_ALMA"+str(period)] = pd.Series(ALMA(period, 0.85, 6, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:103: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_TEMA"+str(period)] = pd.Series(TEMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:106: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_EMA"+str(period)] = pd.Series(EMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:109: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_DEMA"+str(period)] = pd.Series(DEMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:112: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_DPO"+str(period)] = pd.Series(DPO(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:115: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_HMA"+str(period)] = pd.Series(HMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:121: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_StdDev"+str(period)] = pd.Series(StdDev(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:124: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_RSI"+str(period)] = pd.Series(RSI(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_ROC"+str(period)] = pd.Series(ROC(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_TRIX"+str(period)] = pd.Series(TRIX(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:81: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_max"+str(period)] = df[price_type].rolling(period).max()
# /tmp/ipykernel_33334/1214833122.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_min"+str(period)] = df[price_type].rolling(period).min()
# /tmp/ipykernel_33334/1214833122.py:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_median"+str(period)] = df[price_type].rolling(period).median()
# /tmp/ipykernel_33334/1214833122.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_SMA"+str(period)] = pd.Series(SMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:94: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_SMMA"+str(period)] = pd.Series(SMMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_WMA"+str(period)] = pd.Series(WMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:100: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_ALMA"+str(period)] = pd.Series(ALMA(period, 0.85, 6, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:103: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_TEMA"+str(period)] = pd.Series(TEMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:106: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_EMA"+str(period)] = pd.Series(EMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:109: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_DEMA"+str(period)] = pd.Series(DEMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:112: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_DPO"+str(period)] = pd.Series(DPO(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:115: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_HMA"+str(period)] = pd.Series(HMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:121: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_StdDev"+str(period)] = pd.Series(StdDev(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:124: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_RSI"+str(period)] = pd.Series(RSI(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_ROC"+str(period)] = pd.Series(ROC(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_TRIX"+str(period)] = pd.Series(TRIX(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:81: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_max"+str(period)] = df[price_type].rolling(period).max()
# /tmp/ipykernel_33334/1214833122.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_min"+str(period)] = df[price_type].rolling(period).min()
# /tmp/ipykernel_33334/1214833122.py:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_median"+str(period)] = df[price_type].rolling(period).median()
# /tmp/ipykernel_33334/1214833122.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_SMA"+str(period)] = pd.Series(SMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:94: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_SMMA"+str(period)] = pd.Series(SMMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_WMA"+str(period)] = pd.Series(WMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:100: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_ALMA"+str(period)] = pd.Series(ALMA(period, 0.85, 6, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:103: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_TEMA"+str(period)] = pd.Series(TEMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:106: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_EMA"+str(period)] = pd.Series(EMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:109: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_DEMA"+str(period)] = pd.Series(DEMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:112: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_DPO"+str(period)] = pd.Series(DPO(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:115: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_HMA"+str(period)] = pd.Series(HMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:121: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_StdDev"+str(period)] = pd.Series(StdDev(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:124: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_RSI"+str(period)] = pd.Series(RSI(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_ROC"+str(period)] = pd.Series(ROC(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_TRIX"+str(period)] = pd.Series(TRIX(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:81: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_max"+str(period)] = df[price_type].rolling(period).max()
# /tmp/ipykernel_33334/1214833122.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_min"+str(period)] = df[price_type].rolling(period).min()
# /tmp/ipykernel_33334/1214833122.py:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_median"+str(period)] = df[price_type].rolling(period).median()
# /tmp/ipykernel_33334/1214833122.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_SMA"+str(period)] = pd.Series(SMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:94: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_SMMA"+str(period)] = pd.Series(SMMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_WMA"+str(period)] = pd.Series(WMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:100: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_ALMA"+str(period)] = pd.Series(ALMA(period, 0.85, 6, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:103: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_TEMA"+str(period)] = pd.Series(TEMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:106: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_EMA"+str(period)] = pd.Series(EMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:109: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_DEMA"+str(period)] = pd.Series(DEMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:112: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_DPO"+str(period)] = pd.Series(DPO(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:115: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_HMA"+str(period)] = pd.Series(HMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:121: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_StdDev"+str(period)] = pd.Series(StdDev(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:124: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_RSI"+str(period)] = pd.Series(RSI(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_ROC"+str(period)] = pd.Series(ROC(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_TRIX"+str(period)] = pd.Series(TRIX(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:47: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["CCI"+str(period)] = pd.Series(CCI(period, ohlcv))
# /tmp/ipykernel_33334/1214833122.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["CHOP"+str(period)] = pd.Series(CHOP(period, ohlcv))
# /tmp/ipykernel_33334/1214833122.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["VTX"+str(period)+"_plus_vtx"] = pd.Series(np.vectorize(lambda x: x.plus_vtx)(vtx_series))
# /tmp/ipykernel_33334/1214833122.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["VTX"+str(period)+"_minus_vtx"] = pd.Series(np.vectorize(lambda x: x.minus_vtx)(vtx_series))
# /tmp/ipykernel_33334/1214833122.py:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["SOBV"+str(period)] = pd.Series(SOBV(period, ohlcv))
# /tmp/ipykernel_33334/1214833122.py:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["ATR"+str(period)] = pd.Series(ATR(period, ohlcv))
# /tmp/ipykernel_33334/1214833122.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["ForceIndex"+str(period)] = pd.Series(ForceIndex(period, ohlcv))
# /tmp/ipykernel_33334/1214833122.py:81: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_max"+str(period)] = df[price_type].rolling(period).max()
# /tmp/ipykernel_33334/1214833122.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_min"+str(period)] = df[price_type].rolling(period).min()
# /tmp/ipykernel_33334/1214833122.py:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_median"+str(period)] = df[price_type].rolling(period).median()
# /tmp/ipykernel_33334/1214833122.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_SMA"+str(period)] = pd.Series(SMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:94: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_SMMA"+str(period)] = pd.Series(SMMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_WMA"+str(period)] = pd.Series(WMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:100: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_ALMA"+str(period)] = pd.Series(ALMA(period, 0.85, 6, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:103: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_TEMA"+str(period)] = pd.Series(TEMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:106: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_EMA"+str(period)] = pd.Series(EMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:109: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_DEMA"+str(period)] = pd.Series(DEMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:112: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_DPO"+str(period)] = pd.Series(DPO(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:115: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_HMA"+str(period)] = pd.Series(HMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:121: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_StdDev"+str(period)] = pd.Series(StdDev(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:124: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_RSI"+str(period)] = pd.Series(RSI(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_ROC"+str(period)] = pd.Series(ROC(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_TRIX"+str(period)] = pd.Series(TRIX(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:81: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_max"+str(period)] = df[price_type].rolling(period).max()
# /tmp/ipykernel_33334/1214833122.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_min"+str(period)] = df[price_type].rolling(period).min()
# /tmp/ipykernel_33334/1214833122.py:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_median"+str(period)] = df[price_type].rolling(period).median()
# /tmp/ipykernel_33334/1214833122.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_SMA"+str(period)] = pd.Series(SMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:94: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_SMMA"+str(period)] = pd.Series(SMMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_WMA"+str(period)] = pd.Series(WMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:100: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_ALMA"+str(period)] = pd.Series(ALMA(period, 0.85, 6, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:103: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_TEMA"+str(period)] = pd.Series(TEMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:106: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_EMA"+str(period)] = pd.Series(EMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:109: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_DEMA"+str(period)] = pd.Series(DEMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:112: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_DPO"+str(period)] = pd.Series(DPO(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:115: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_HMA"+str(period)] = pd.Series(HMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:121: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_StdDev"+str(period)] = pd.Series(StdDev(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:124: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_RSI"+str(period)] = pd.Series(RSI(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_ROC"+str(period)] = pd.Series(ROC(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_TRIX"+str(period)] = pd.Series(TRIX(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:81: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_max"+str(period)] = df[price_type].rolling(period).max()
# /tmp/ipykernel_33334/1214833122.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_min"+str(period)] = df[price_type].rolling(period).min()
# /tmp/ipykernel_33334/1214833122.py:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_median"+str(period)] = df[price_type].rolling(period).median()
# /tmp/ipykernel_33334/1214833122.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_SMA"+str(period)] = pd.Series(SMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:94: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_SMMA"+str(period)] = pd.Series(SMMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_WMA"+str(period)] = pd.Series(WMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:100: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_ALMA"+str(period)] = pd.Series(ALMA(period, 0.85, 6, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:103: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_TEMA"+str(period)] = pd.Series(TEMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:106: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_EMA"+str(period)] = pd.Series(EMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:109: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_DEMA"+str(period)] = pd.Series(DEMA(period, dct[price_type]))
# ...
#   df[price_type+"_RSI"+str(period)] = pd.Series(RSI(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_ROC"+str(period)] = pd.Series(ROC(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_TRIX"+str(period)] = pd.Series(TRIX(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:81: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_max"+str(period)] = df[price_type].rolling(period).max()
# /tmp/ipykernel_33334/1214833122.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_min"+str(period)] = df[price_type].rolling(period).min()
# /tmp/ipykernel_33334/1214833122.py:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_median"+str(period)] = df[price_type].rolling(period).median()
# /tmp/ipykernel_33334/1214833122.py:88: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_quantile25_"+str(period)] = df[price_type].rolling(period).quantile(0.25)
# /tmp/ipykernel_33334/1214833122.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_quantile75_"+str(period)] = df[price_type].rolling(period).quantile(0.75)
# /tmp/ipykernel_33334/1214833122.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_SMA"+str(period)] = pd.Series(SMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:94: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_SMMA"+str(period)] = pd.Series(SMMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_WMA"+str(period)] = pd.Series(WMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:100: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_ALMA"+str(period)] = pd.Series(ALMA(period, 0.85, 6, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:103: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_TEMA"+str(period)] = pd.Series(TEMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:106: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_EMA"+str(period)] = pd.Series(EMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:109: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_DEMA"+str(period)] = pd.Series(DEMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:112: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_DPO"+str(period)] = pd.Series(DPO(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:115: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_HMA"+str(period)] = pd.Series(HMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:121: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_StdDev"+str(period)] = pd.Series(StdDev(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:124: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_RSI"+str(period)] = pd.Series(RSI(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_ROC"+str(period)] = pd.Series(ROC(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_TRIX"+str(period)] = pd.Series(TRIX(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:81: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_max"+str(period)] = df[price_type].rolling(period).max()
# /tmp/ipykernel_33334/1214833122.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_min"+str(period)] = df[price_type].rolling(period).min()
# /tmp/ipykernel_33334/1214833122.py:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_median"+str(period)] = df[price_type].rolling(period).median()
# /tmp/ipykernel_33334/1214833122.py:88: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_quantile25_"+str(period)] = df[price_type].rolling(period).quantile(0.25)
# /tmp/ipykernel_33334/1214833122.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_quantile75_"+str(period)] = df[price_type].rolling(period).quantile(0.75)
# /tmp/ipykernel_33334/1214833122.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_SMA"+str(period)] = pd.Series(SMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:94: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_SMMA"+str(period)] = pd.Series(SMMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_WMA"+str(period)] = pd.Series(WMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:100: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_ALMA"+str(period)] = pd.Series(ALMA(period, 0.85, 6, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:103: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_TEMA"+str(period)] = pd.Series(TEMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:106: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_EMA"+str(period)] = pd.Series(EMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:109: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_DEMA"+str(period)] = pd.Series(DEMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:112: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_DPO"+str(period)] = pd.Series(DPO(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:115: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_HMA"+str(period)] = pd.Series(HMA(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:121: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_StdDev"+str(period)] = pd.Series(StdDev(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:124: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_RSI"+str(period)] = pd.Series(RSI(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_ROC"+str(period)] = pd.Series(ROC(period, dct[price_type]))
# /tmp/ipykernel_33334/1214833122.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[price_type+"_TRIX"+str(period)] = pd.Series(TRIX(period, dct[price_type]))

# %%
# print(f'BB: {BB(20, 2, close)[-1]}')
# print(f'ChaikinOsc: {ChaikinOsc(3, 10, ohlcv)[-1]}')
# print(f'ChandeKrollStop: {ChandeKrollStop(10, 2, 9, ohlcv)[-1]}')
# print(f'DonchianChannels: {DonchianChannels(20, ohlcv)[-1]}')
# print(f'Ichimoku: {Ichimoku(26, 9, 52, 52, 26, ohlcv)[-1]}')
# print(f'KeltnerChannels: {KeltnerChannels(20, 26, 1, 1, ohlcv)[-1]}')
# print(f"SAR: {ParabolicSAR(0.02, 0.02, 0.2, ohlcv)[-20:]}")
# print(f'SFX: {SFX(12, 12, 3, ohlcv)[-1]}')
# print(f'Stoch: {Stoch(14, 3, ohlcv)[-1]}')
# print(f'StochRSI: {StochRSI(14, 14, 3, 3, close)[-1]}')
# print(f'SuperTrend: {SuperTrend(10, 3, ohlcv)[-20:]}')

# %%
df
# Out:
#                  time_open      open      high       low     close  \
# 0      2017-12-19 15:00:00  18569.52  18650.02  18545.11  18620.01
# 1      2017-12-19 16:00:00  18620.02  18695.20  18165.99  18234.89
# 2      2017-12-19 17:00:00  18259.40  18259.40  16300.00  16852.00
# 3      2017-12-19 18:00:00  16890.00  17800.00  16550.22  17250.00
# 4      2017-12-19 19:00:00  17214.20  17900.00  17100.00  17550.50
# ...                    ...       ...       ...       ...       ...
# 39376  2022-06-22 06:00:00  20897.00  20943.17  20551.00  20723.52
# 39377  2022-06-22 07:00:00  20723.51  20736.68  20421.38  20587.01
# 39378  2022-06-22 08:00:00  20587.01  20719.21  20388.01  20411.24
# 39379  2022-06-22 09:00:00  20411.23  20526.67  20330.00  20466.47
# 39380  2022-06-22 10:00:00  20466.47  20567.60  20253.96  20317.88
#
#             volume  quote_asset_volume  number_of_trades  \
# 0       338.319586        6.292816e+06            2568.0
# 1       505.051461        9.298289e+06            4418.0
# 2      1831.436840        3.155096e+07           15372.0
# 3      1226.949207        2.113936e+07           11082.0
# 4       823.862800        1.443043e+07            6158.0
# ...            ...                 ...               ...
# 39376  2613.774410        5.412753e+07           42193.0
# 39377  4195.854000        8.638902e+07           58827.0
# 39378  3271.915890        6.732365e+07           53095.0
# 39379  3588.324010        7.332763e+07           53154.0
# 39380  2923.225220        5.969947e+07           45920.0
#
#        taker_buy_base_asset_volume  taker_buy_quote_asset_volume  ...  \
# 0                       128.750204                  2.395303e+06  ...
# 1                       198.079068                  3.645787e+06  ...
# 2                       827.913384                  1.426553e+07  ...
# 3                       612.086815                  1.057065e+07  ...
# 4                       396.400387                  6.944349e+06  ...
# ...                            ...                           ...  ...
# 39376                  1245.791750                  2.580072e+07  ...
# 39377                  1911.811000                  3.937325e+07  ...
# 39378                  1526.045120                  3.140632e+07  ...
# 39379                  1650.636910                  3.372889e+07  ...
# 39380                  1263.597380                  2.580499e+07  ...
#
#         low_TEMA192    low_EMA192   low_DEMA192  low_DPO192    low_HMA192  \
# 0               NaN           NaN           NaN         NaN           NaN
# 1               NaN           NaN           NaN         NaN           NaN
# 2               NaN           NaN           NaN         NaN           NaN
# 3               NaN           NaN           NaN         NaN           NaN
# 4               NaN           NaN           NaN         NaN           NaN
# ...             ...           ...           ...         ...           ...
# 39376  19206.969001  21330.865557  18955.260293 -123.756927  20034.578287
# 39377  19225.358680  21321.440836  18961.126188  -56.781979  20074.808709
# 39378  19242.566591  21311.767977  18966.339927  -41.749740  20112.321602
# 39379  19257.856087  21301.594216  18970.402786 -104.722240  20147.057758
# 39380  19270.709206  21290.737903  18972.960084 -152.211615  20178.943761
#
#        low_MeanDev192  low_StdDev192  low_RSI192  low_ROC192  low_TRIX192
# 0                 NaN            NaN         NaN         NaN          NaN
# 1                 NaN            NaN         NaN         NaN          NaN
# 2                 NaN            NaN         NaN         NaN          NaN
# 3                 NaN            NaN         NaN         NaN          NaN
# 4                 NaN            NaN         NaN         NaN          NaN
# ...               ...            ...         ...         ...          ...
# 39376      827.511214    1095.037286   45.469125   -6.270110   -10.436187
# 39377      821.726126    1091.216163   45.289639   -6.137641   -10.436088
# 39378      820.430899    1090.909154   45.243420   -2.239223   -10.435477
# 39379      819.444646    1090.646080   45.162879   -2.475295   -10.434385
# 39380      816.397051    1089.037526   45.057189   -5.032972   -10.432847
#
# [39381 rows x 680 columns]

# %%
df["label"] = (df["close"] - df["close"].shift(1) > 0).shift(-1)
# Out:
# /tmp/ipykernel_33334/945242221.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["label"] = (df["close"] - df["close"].shift(1) > 0).shift(-1)

# %%
for c in df.columns:
    print(c)
# Out:
# time_open
# open
# high
# low
# close
# volume
# quote_asset_volume
# number_of_trades
# taker_buy_base_asset_volume
# taker_buy_quote_asset_volume
# exchange_reserve
# exchange_reserve_USD
# exchange_inflow
# exchange_outflow
# exchange_in_house_flow
# exchange_whale_ratio
# exchange_supply_ratio
# miner_reserve
# miner_reserve_USD
# miner_outflow
# miner_inflow
# coinbase_premium_index
# CoppockCurve
# KAMA
# KST_kst
# KST_signal
# MACD_macd
# MACD_signal
# MassIndex
# OBV
# KVO
# VWAP
# AccuDist
# BOP
# UO
# TSI
# AO
# CCI2
# CHOP2
# VTX2_plus_vtx
# VTX2_minus_vtx
# SOBV2
# ATR2
# ForceIndex2
# ADX_plus_di
# ADX_minus_di
# ADX_adx
# open_max2
# open_min2
# open_median2
# open_SMA2
# open_SMMA2
# open_WMA2
# open_ALMA2
# open_TEMA2
# open_EMA2
# open_DEMA2
# open_DPO2
# open_HMA2
# open_MeanDev2
# open_StdDev2
# open_RSI2
# open_ROC2
# open_TRIX2
# close_max2
# close_min2
# close_median2
# close_SMA2
# close_SMMA2
# close_WMA2
# close_ALMA2
# close_TEMA2
# close_EMA2
# close_DEMA2
# close_DPO2
# close_HMA2
# close_MeanDev2
# close_StdDev2
# close_RSI2
# close_ROC2
# close_TRIX2
# high_max2
# high_min2
# high_median2
# high_SMA2
# high_SMMA2
# high_WMA2
# high_ALMA2
# high_TEMA2
# high_EMA2
# high_DEMA2
# high_DPO2
# high_HMA2
# high_MeanDev2
# high_StdDev2
# high_RSI2
# high_ROC2
# high_TRIX2
# low_max2
# low_min2
# low_median2
# low_SMA2
# low_SMMA2
# low_WMA2
# low_ALMA2
# low_TEMA2
# low_EMA2
# low_DEMA2
# low_DPO2
# low_HMA2
# low_MeanDev2
# low_StdDev2
# low_RSI2
# low_ROC2
# low_TRIX2
# CCI4
# CHOP4
# VTX4_plus_vtx
# VTX4_minus_vtx
# SOBV4
# ATR4
# ForceIndex4
# open_max4
# open_min4
# open_median4
# open_SMA4
# open_SMMA4
# open_WMA4
# open_ALMA4
# open_TEMA4
# open_EMA4
# open_DEMA4
# open_DPO4
# open_HMA4
# open_MeanDev4
# open_StdDev4
# open_RSI4
# open_ROC4
# open_TRIX4
# close_max4
# close_min4
# close_median4
# close_SMA4
# close_SMMA4
# close_WMA4
# close_ALMA4
# close_TEMA4
# close_EMA4
# close_DEMA4
# close_DPO4
# close_HMA4
# close_MeanDev4
# close_StdDev4
# close_RSI4
# close_ROC4
# close_TRIX4
# high_max4
# high_min4
# high_median4
# high_SMA4
# high_SMMA4
# high_WMA4
# high_ALMA4
# high_TEMA4
# high_EMA4
# high_DEMA4
# high_DPO4
# high_HMA4
# high_MeanDev4
# high_StdDev4
# high_RSI4
# high_ROC4
# high_TRIX4
# low_max4
# low_min4
# low_median4
# low_SMA4
# low_SMMA4
# low_WMA4
# low_ALMA4
# low_TEMA4
# low_EMA4
# low_DEMA4
# low_DPO4
# low_HMA4
# low_MeanDev4
# low_StdDev4
# low_RSI4
# low_ROC4
# low_TRIX4
# CCI8
# CHOP8
# VTX8_plus_vtx
# VTX8_minus_vtx
# SOBV8
# ATR8
# ForceIndex8
# open_max8
# open_min8
# open_median8
# open_SMA8
# open_SMMA8
# open_WMA8
# open_ALMA8
# open_TEMA8
# open_EMA8
# open_DEMA8
# open_DPO8
# open_HMA8
# open_MeanDev8
# open_StdDev8
# open_RSI8
# open_ROC8
# open_TRIX8
# close_max8
# close_min8
# close_median8
# close_SMA8
# close_SMMA8
# close_WMA8
# close_ALMA8
# close_TEMA8
# close_EMA8
# close_DEMA8
# close_DPO8
# close_HMA8
# close_MeanDev8
# close_StdDev8
# close_RSI8
# close_ROC8
# close_TRIX8
# high_max8
# high_min8
# high_median8
# high_SMA8
# high_SMMA8
# high_WMA8
# high_ALMA8
# high_TEMA8
# high_EMA8
# high_DEMA8
# high_DPO8
# high_HMA8
# high_MeanDev8
# high_StdDev8
# high_RSI8
# high_ROC8
# high_TRIX8
# low_max8
# low_min8
# low_median8
# low_SMA8
# low_SMMA8
# low_WMA8
# low_ALMA8
# low_TEMA8
# low_EMA8
# low_DEMA8
# low_DPO8
# low_HMA8
# low_MeanDev8
# low_StdDev8
# low_RSI8
# low_ROC8
# low_TRIX8
# CCI12
# CHOP12
# VTX12_plus_vtx
# VTX12_minus_vtx
# SOBV12
# ATR12
# ForceIndex12
# open_max12
# open_min12
# open_median12
# open_quantile25_12
# open_quantile75_12
# open_SMA12
# open_SMMA12
# open_WMA12
# open_ALMA12
# open_TEMA12
# open_EMA12
# open_DEMA12
# open_DPO12
# open_HMA12
# open_MeanDev12
# open_StdDev12
# open_RSI12
# open_ROC12
# open_TRIX12
# close_max12
# close_min12
# close_median12
# close_quantile25_12
# close_quantile75_12
# close_SMA12
# close_SMMA12
# close_WMA12
# close_ALMA12
# close_TEMA12
# close_EMA12
# close_DEMA12
# close_DPO12
# close_HMA12
# close_MeanDev12
# close_StdDev12
# close_RSI12
# close_ROC12
# close_TRIX12
# high_max12
# high_min12
# high_median12
# high_quantile25_12
# high_quantile75_12
# high_SMA12
# high_SMMA12
# high_WMA12
# high_ALMA12
# high_TEMA12
# high_EMA12
# high_DEMA12
# high_DPO12
# high_HMA12
# high_MeanDev12
# high_StdDev12
# high_RSI12
# high_ROC12
# high_TRIX12
# low_max12
# low_min12
# low_median12
# low_quantile25_12
# low_quantile75_12
# low_SMA12
# low_SMMA12
# low_WMA12
# low_ALMA12
# low_TEMA12
# low_EMA12
# low_DEMA12
# low_DPO12
# low_HMA12
# low_MeanDev12
# low_StdDev12
# low_RSI12
# low_ROC12
# low_TRIX12
# CCI24
# CHOP24
# VTX24_plus_vtx
# VTX24_minus_vtx
# SOBV24
# ATR24
# ForceIndex24
# open_max24
# open_min24
# open_median24
# open_quantile25_24
# open_quantile75_24
# open_SMA24
# open_SMMA24
# open_WMA24
# open_ALMA24
# open_TEMA24
# open_EMA24
# open_DEMA24
# open_DPO24
# open_HMA24
# open_MeanDev24
# open_StdDev24
# open_RSI24
# open_ROC24
# open_TRIX24
# close_max24
# close_min24
# close_median24
# close_quantile25_24
# close_quantile75_24
# close_SMA24
# close_SMMA24
# close_WMA24
# close_ALMA24
# close_TEMA24
# close_EMA24
# close_DEMA24
# close_DPO24
# close_HMA24
# close_MeanDev24
# close_StdDev24
# close_RSI24
# close_ROC24
# close_TRIX24
# high_max24
# high_min24
# high_median24
# high_quantile25_24
# high_quantile75_24
# high_SMA24
# high_SMMA24
# high_WMA24
# high_ALMA24
# high_TEMA24
# high_EMA24
# high_DEMA24
# high_DPO24
# high_HMA24
# high_MeanDev24
# high_StdDev24
# high_RSI24
# high_ROC24
# high_TRIX24
# low_max24
# low_min24
# low_median24
# low_quantile25_24
# low_quantile75_24
# low_SMA24
# low_SMMA24
# low_WMA24
# low_ALMA24
# low_TEMA24
# low_EMA24
# low_DEMA24
# low_DPO24
# low_HMA24
# low_MeanDev24
# low_StdDev24
# low_RSI24
# low_ROC24
# low_TRIX24
# CCI48
# CHOP48
# VTX48_plus_vtx
# VTX48_minus_vtx
# SOBV48
# ATR48
# ForceIndex48
# open_max48
# open_min48
# open_median48
# open_quantile25_48
# open_quantile75_48
# open_SMA48
# open_SMMA48
# open_WMA48
# open_ALMA48
# open_TEMA48
# open_EMA48
# open_DEMA48
# open_DPO48
# open_HMA48
# open_MeanDev48
# open_StdDev48
# open_RSI48
# open_ROC48
# open_TRIX48
# close_max48
# close_min48
# close_median48
# close_quantile25_48
# close_quantile75_48
# close_SMA48
# close_SMMA48
# close_WMA48
# close_ALMA48
# close_TEMA48
# close_EMA48
# close_DEMA48
# close_DPO48
# close_HMA48
# close_MeanDev48
# close_StdDev48
# close_RSI48
# close_ROC48
# close_TRIX48
# high_max48
# high_min48
# high_median48
# high_quantile25_48
# high_quantile75_48
# high_SMA48
# high_SMMA48
# high_WMA48
# high_ALMA48
# high_TEMA48
# high_EMA48
# high_DEMA48
# high_DPO48
# high_HMA48
# high_MeanDev48
# high_StdDev48
# high_RSI48
# high_ROC48
# high_TRIX48
# low_max48
# low_min48
# low_median48
# low_quantile25_48
# low_quantile75_48
# low_SMA48
# low_SMMA48
# low_WMA48
# low_ALMA48
# low_TEMA48
# low_EMA48
# low_DEMA48
# low_DPO48
# low_HMA48
# low_MeanDev48
# low_StdDev48
# low_RSI48
# low_ROC48
# low_TRIX48
# CCI96
# CHOP96
# VTX96_plus_vtx
# VTX96_minus_vtx
# SOBV96
# ATR96
# ForceIndex96
# open_max96
# open_min96
# open_median96
# open_quantile25_96
# open_quantile75_96
# open_SMA96
# open_SMMA96
# open_WMA96
# open_ALMA96
# open_TEMA96
# open_EMA96
# open_DEMA96
# open_DPO96
# open_HMA96
# open_MeanDev96
# open_StdDev96
# open_RSI96
# open_ROC96
# open_TRIX96
# close_max96
# close_min96
# close_median96
# close_quantile25_96
# close_quantile75_96
# close_SMA96
# close_SMMA96
# close_WMA96
# close_ALMA96
# close_TEMA96
# close_EMA96
# close_DEMA96
# close_DPO96
# close_HMA96
# close_MeanDev96
# close_StdDev96
# close_RSI96
# close_ROC96
# close_TRIX96
# high_max96
# high_min96
# high_median96
# high_quantile25_96
# high_quantile75_96
# high_SMA96
# high_SMMA96
# high_WMA96
# high_ALMA96
# high_TEMA96
# high_EMA96
# high_DEMA96
# high_DPO96
# high_HMA96
# high_MeanDev96
# high_StdDev96
# high_RSI96
# high_ROC96
# high_TRIX96
# low_max96
# low_min96
# low_median96
# low_quantile25_96
# low_quantile75_96
# low_SMA96
# low_SMMA96
# low_WMA96
# low_ALMA96
# low_TEMA96
# low_EMA96
# low_DEMA96
# low_DPO96
# low_HMA96
# low_MeanDev96
# low_StdDev96
# low_RSI96
# low_ROC96
# low_TRIX96
# CCI192
# CHOP192
# VTX192_plus_vtx
# VTX192_minus_vtx
# SOBV192
# ATR192
# ForceIndex192
# open_max192
# open_min192
# open_median192
# open_quantile25_192
# open_quantile75_192
# open_SMA192
# open_SMMA192
# open_WMA192
# open_ALMA192
# open_TEMA192
# open_EMA192
# open_DEMA192
# open_DPO192
# open_HMA192
# open_MeanDev192
# open_StdDev192
# open_RSI192
# open_ROC192
# open_TRIX192
# close_max192
# close_min192
# close_median192
# close_quantile25_192
# close_quantile75_192
# close_SMA192
# close_SMMA192
# close_WMA192
# close_ALMA192
# close_TEMA192
# close_EMA192
# close_DEMA192
# close_DPO192
# close_HMA192
# close_MeanDev192
# close_StdDev192
# close_RSI192
# close_ROC192
# close_TRIX192
# high_max192
# high_min192
# high_median192
# high_quantile25_192
# high_quantile75_192
# high_SMA192
# high_SMMA192
# high_WMA192
# high_ALMA192
# high_TEMA192
# high_EMA192
# high_DEMA192
# high_DPO192
# high_HMA192
# high_MeanDev192
# high_StdDev192
# high_RSI192
# high_ROC192
# high_TRIX192
# low_max192
# low_min192
# low_median192
# low_quantile25_192
# low_quantile75_192
# low_SMA192
# low_SMMA192
# low_WMA192
# low_ALMA192
# low_TEMA192
# low_EMA192
# low_DEMA192
# low_DPO192
# low_HMA192
# low_MeanDev192
# low_StdDev192
# low_RSI192
# low_ROC192
# low_TRIX192
# label

# %%
df["exchange_netflow"] = df["exchange_inflow"] - df["exchange_outflow"]
df["miner_netflow"] = df["miner_inflow"] - df["miner_outflow"]
# Out:
# /tmp/ipykernel_33334/3051118061.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["exchange_netflow"] = df["exchange_inflow"] - df["exchange_outflow"]
# /tmp/ipykernel_33334/3051118061.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["miner_netflow"] = df["miner_inflow"] - df["miner_outflow"]

# %%
cryptoquant_indicators = ["exchange_reserve", "exchange_inflow", "exchange_outflow", "exchange_netflow", "miner_netflow", "exchange_in_house_flow", "exchange_whale_ratio", "exchange_supply_ratio", "miner_reserve", "miner_reserve_USD", "miner_outflow", "miner_inflow", "coinbase_premium_index"]

# %%
for period in periods:
    for cryptoquant_indicator in cryptoquant_indicators:  
        
        if period >= 12:
            df[cryptoquant_indicator+"_quantile25_"+str(period)] = df[cryptoquant_indicator].rolling(period).quantile(0.25)
            df[cryptoquant_indicator+"_quantile75_"+str(period)] = df[cryptoquant_indicator].rolling(period).quantile(0.75)
        
        df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
        shift(df, cryptoquant_indicator+"_SMA"+str(period))
        
        df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
        
        df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
        
        df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
        
        df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
        shift(df, cryptoquant_indicator+"_MeanDev"+str(period))  
        
        df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
        shift(df, cryptoquant_indicator+"_StdDev"+str(period))
# Out:
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# ...
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_quantile25_"+str(period)] = df[cryptoquant_indicator].rolling(period).quantile(0.25)
# /tmp/ipykernel_33334/2548366844.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_quantile75_"+str(period)] = df[cryptoquant_indicator].rolling(period).quantile(0.75)
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_quantile25_"+str(period)] = df[cryptoquant_indicator].rolling(period).quantile(0.25)
# /tmp/ipykernel_33334/2548366844.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_quantile75_"+str(period)] = df[cryptoquant_indicator].rolling(period).quantile(0.75)
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_quantile25_"+str(period)] = df[cryptoquant_indicator].rolling(period).quantile(0.25)
# /tmp/ipykernel_33334/2548366844.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_quantile75_"+str(period)] = df[cryptoquant_indicator].rolling(period).quantile(0.75)
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_quantile25_"+str(period)] = df[cryptoquant_indicator].rolling(period).quantile(0.25)
# /tmp/ipykernel_33334/2548366844.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_quantile75_"+str(period)] = df[cryptoquant_indicator].rolling(period).quantile(0.75)
# /tmp/ipykernel_33334/2548366844.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_SMA"+str(period)] = pd.Series(SMA(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_max"+str(period)] = df[cryptoquant_indicator].rolling(period).max()
# /tmp/ipykernel_33334/2548366844.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_min"+str(period)] = df[cryptoquant_indicator].rolling(period).min()
# /tmp/ipykernel_33334/2548366844.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_median"+str(period)] = df[cryptoquant_indicator].rolling(period).median()
# /tmp/ipykernel_33334/2548366844.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_MeanDev"+str(period)] = pd.Series(MeanDev(period, df[cryptoquant_indicator].to_numpy()))
# /tmp/ipykernel_33334/2548366844.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[cryptoquant_indicator+"_StdDev"+str(period)] = pd.Series(StdDev(period, df[cryptoquant_indicator].to_numpy()))

# %%
df.isna().sum().sum()
# Out:
# 79633

# %%
df.ffill(inplace=True)

# %%
df.isna().sum().sum()
# Out:
# 79632

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                  time_open      open      high       low     close  \
# 574    2018-01-12 14:00:00  13861.00  13966.63  13700.00  13722.04
# 575    2018-01-12 15:00:00  13722.04  13770.00  13490.00  13650.99
# 576    2018-01-12 16:00:00  13630.07  13670.00  13301.99  13476.03
# 577    2018-01-12 17:00:00  13496.99  13977.00  13476.03  13941.22
# 578    2018-01-12 18:00:00  13940.00  14109.78  13832.13  13900.02
# ...                    ...       ...       ...       ...       ...
# 39376  2022-06-22 06:00:00  20897.00  20943.17  20551.00  20723.52
# 39377  2022-06-22 07:00:00  20723.51  20736.68  20421.38  20587.01
# 39378  2022-06-22 08:00:00  20587.01  20719.21  20388.01  20411.24
# 39379  2022-06-22 09:00:00  20411.23  20526.67  20330.00  20466.47
# 39380  2022-06-22 10:00:00  20466.47  20567.60  20253.96  20317.88
#
#             volume  quote_asset_volume  number_of_trades  \
# 574     806.940643        1.117058e+07            7050.0
# 575     600.936336        8.184325e+06            5003.0
# 576     507.069800        6.832269e+06            4107.0
# 577     610.208586        8.444387e+06            5339.0
# 578     714.759093        9.978926e+06            5885.0
# ...            ...                 ...               ...
# 39376  2613.774410        5.412753e+07           42193.0
# 39377  4195.854000        8.638902e+07           58827.0
# 39378  3271.915890        6.732365e+07           53095.0
# 39379  3588.324010        7.332763e+07           53154.0
# 39380  2923.225220        5.969947e+07           45920.0
#
#        taker_buy_base_asset_volume  taker_buy_quote_asset_volume  ...  \
# 574                     297.371551                  4.117218e+06  ...
# 575                     312.844271                  4.260507e+06  ...
# 576                     249.539862                  3.363206e+06  ...
# 577                     354.586102                  4.908027e+06  ...
# 578                     381.063577                  5.318427e+06  ...
# ...                            ...                           ...  ...
# 39376                  1245.791750                  2.580072e+07  ...
# 39377                  1911.811000                  3.937325e+07  ...
# 39378                  1526.045120                  3.140632e+07  ...
# 39379                  1650.636910                  3.372889e+07  ...
# 39380                  1263.597380                  2.580499e+07  ...
#
#        miner_inflow_MeanDev192  miner_inflow_StdDev192  \
# 574                  86.684581              112.541082
# 575                  86.531619              112.415892
# 576                  86.462320              112.340843
# 577                  86.105569              112.243424
# 578                  86.373760              112.348545
# ...                        ...                     ...
# 39376               118.497216              312.753916
# 39377               118.576692              312.825290
# 39378               118.564919              312.815596
# 39379               117.956444              312.765296
# 39380               115.182854              310.784816
#
#        coinbase_premium_index_quantile25_192  \
# 574                                -0.049978
# 575                                -0.055607
# 576                                -0.055607
# 577                                -0.055607
# 578                                -0.055607
# ...                                      ...
# 39376                              -0.150101
# 39377                              -0.150101
# 39378                              -0.150101
# 39379                              -0.149941
# 39380                              -0.149509
#
#        coinbase_premium_index_quantile75_192  coinbase_premium_index_SMA192  \
# 574                                 0.725039                       0.421970
# 575                                 0.698683                       0.413423
# 576                                 0.691596                       0.404459
# 577                                 0.683768                       0.400878
# 578                                 0.683768                       0.400865
# ...                                      ...                            ...
# 39376                              -0.104851                      -0.130318
# 39377                              -0.104851                      -0.130209
# 39378                              -0.104709                      -0.130093
# 39379                              -0.104709                      -0.129716
# 39380                              -0.104709                      -0.129537
#
#        coinbase_premium_index_max192  coinbase_premium_index_min192  \
# 574                         7.234200                      -1.623604
# 575                         7.234200                      -1.623604
# 576                         7.234200                      -1.623604
# 577                         7.234200                      -1.623604
# 578                         7.234200                      -1.623604
# ...                              ...                            ...
# 39376                      -0.008152                      -0.340363
# 39377                      -0.008152                      -0.340363
# 39378                      -0.008152                      -0.340363
# 39379                      -0.008152                      -0.340363
# 39380                      -0.008152                      -0.340363
#
#        coinbase_premium_index_median192  coinbase_premium_index_MeanDev192  \
# 574                            0.307979                           0.578805
# 575                            0.304188                           0.577421
# 576                            0.302183                           0.569536
# 577                            0.300520                           0.569593
# 578                            0.300520                           0.569578
# ...                                 ...                                ...
# 39376                         -0.127812                           0.029710
# 39377                         -0.127420                           0.029813
# 39378                         -0.127420                           0.029924
# 39379                         -0.127096                           0.029722
# 39380                         -0.127096                           0.029533
#
#        coinbase_premium_index_StdDev192
# 574                            0.888767
# 575                            0.888133
# 576                            0.881235
# 577                            0.881395
# 578                            0.881395
# ...                                 ...
# 39376                          0.040324
# 39377                          0.040352
# 39378                          0.040421
# 39379                          0.040255
# 39380                          0.040143
#
# [38807 rows x 1437 columns]

# %%
# df.to_csv("../../data/features_with_cryptoquant_data_df.csv")
