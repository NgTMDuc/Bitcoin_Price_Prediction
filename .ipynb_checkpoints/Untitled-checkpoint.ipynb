# %%
from label.label import label
import pandas as pd

df = label("binance-BTCUSDT-1m.csv")
df
# Out:
#                          open      high       low     close     volume  \
# Time_UTC_Start
# 2018-07-18 11:00:00   7403.62   7409.77   7400.74   7405.01  35.159664
# 2018-07-18 12:00:00   7418.02   7419.99   7416.55   7419.98  44.474849
# 2018-07-18 13:00:00   7435.90   7437.02   7431.00   7437.02  42.365364
# 2018-07-18 14:00:00   7458.14   7459.36   7445.03   7451.30  25.105532
# 2018-07-18 15:00:00   7451.71   7453.01   7442.10   7444.30  60.280231
# ...                       ...       ...       ...       ...        ...
# 2022-05-07 03:00:00  35953.63  35953.64  35943.60  35951.24   6.376430
# 2022-05-07 04:00:00  35812.22  35826.14  35812.21  35826.14   6.066650
# 2022-05-07 05:00:00  35746.62  35768.06  35722.24  35768.05  34.156320
# 2022-05-07 06:00:00  35898.96  35903.80  35890.03  35900.00  16.707700
# 2022-05-07 07:00:00  35806.28  35806.28  35805.80  35805.80   3.683200
#
#                      quote_asset_volume  number_of_trades  base_asset_volume  \
# Time_UTC_Start
# ...

# %%
df.to_csv("binance_btc_1h.csv")

# %%
df
