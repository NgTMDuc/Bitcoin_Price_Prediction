# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import sys
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.metrics import roc_auc_score, mean_squared_error
import math

# %%
def label(df, t=15):
#     df = df[df.shape[0] % t:]
    df2 = df.groupby(np.arange(len(df))//t, axis=0).agg({'Timestamp': 'min', 'Open': 'first', 'High': 'max', 'Low': 'min', 'Close': 'last',
                                'N/A': 'sum', 'Timestamp End': 'max', 'N/A.1': 'sum', 'N/A.2': 'sum', 'N/A.3': 'sum',
                                'N/A.4': 'sum', 'N/A.5': 'sum', 'Time_UTC_Start': 'first'})
    df2.rename(columns = {'N/A': 'Volumn', 'N/A.1': 'Quote_asset_volume', 'N/A.2': 'Number_of_trades',
                         'N/A.3': 'Taker_buy_base_asset_volume', 'N/A.4': 'Taker_buy_quote_asset_volume'}, inplace = True)
    length = df2.shape[0]
    op = df2['Open'].values.reshape(length,1)
    cl = df2['Close'].values.reshape(length,1 )
    v = np.ones((length, 1)) * (op < cl)
    df2['label'] = v
    df2.index = df2["Timestamp"]
    df2.drop(columns=["Timestamp", "N/A.5"], inplace=True)
    return df2

# %%
df = pd.read_csv('../binance-BTCUSDT-1m.csv')

# %%
df = df.iloc[5:]

# %%
df = label(df, t=60)

# %%
df
# Out:
#                    Open      High       Low     Close       Volumn  \
# Timestamp
# 1531910340000   7370.00   7433.32   7365.10   7430.33  1490.468839
# 1531913940000   7430.33   7472.02   7406.23   7465.50  2012.947940
# 1531917540000   7465.53   7467.74   7406.26   7415.33  1705.126043
# 1531921140000   7415.34   7531.30   7386.12   7446.93  3962.214090
# 1531924740000   7446.94   7460.28   7360.40   7434.15  2327.609840
# ...                 ...       ...       ...       ...          ...
# 1651894740000  35823.05  35895.61  35755.85  35814.49   970.311790
# 1651898340000  35814.49  35897.44  35722.24  35821.68   989.732570
# 1651901940000  35821.69  35909.75  35794.31  35858.19   814.217850
# 1651905540000  35858.19  35912.00  35790.02  35902.74  1330.810940
# 1651909140000  35902.75  35956.51  35880.47  35951.69   368.392130
#
#                Timestamp End  Quote_asset_volume  Number_of_trades  \
# Timestamp
# 1531910340000  1531913939999        1.103223e+07              9251
# 1531913940000  1531917539999        1.497337e+07             11142
# 1531917540000  1531921139999        1.268634e+07             10309
# 1531921140000  1531924739999        2.955422e+07             19378
# 1531924740000  1531928339999        1.726583e+07             13522
# ...                      ...                 ...               ...
# 1651894740000  1651898339999        3.476291e+07             23856
# 1651898340000  1651901939999        3.544653e+07             24154
# 1651901940000  1651905539999        2.919114e+07             22472
# 1651905540000  1651909139999        4.768683e+07             24694
# 1651909140000  1651910039999        1.323538e+07              7430
#
#                Taker_buy_base_asset_volume  Taker_buy_quote_asset_volume  \
# Timestamp
# 1531910340000                   851.254378                  6.301175e+06
# 1531913940000                  1165.063229                  8.665742e+06
# 1531917540000                   905.548831                  6.737553e+06
# 1531921140000                  2034.411172                  1.518088e+07
# 1531924740000                  1114.741065                  8.270858e+06
# ...                                    ...                           ...
# 1651894740000                   482.353610                  1.727962e+07
# 1651898340000                   445.450930                  1.595071e+07
# 1651901940000                   409.742390                  1.468973e+07
#        Taker_buy_base_asset_volume  Taker_buy_quote_asset_volume  label
# 0                      1061.254371                  7.873135e+06    1.0
# 1                      1566.110620                  1.166464e+07    1.0
# 2                      1534.280510                  1.146082e+07    0.0
# 3                       907.501465                  6.774638e+06    0.0
# 4                      1518.376834                  1.124020e+07    1.0
# ...                            ...                           ...    ...
# 33304                   482.353610                  1.727962e+07    0.0
# 33305                   445.450930                  1.595071e+07    1.0
# 33306                   409.742390                  1.468973e+07    1.0
# 33307                   552.020890                  1.978468e+07    1.0
# 33308                   228.147900                  8.196411e+06    1.0
#
# [33309 rows x 13 columns]

# %%
df.index = df['Time_UTC_Start']

# %%
del df['Timestamp End'], df['Time_UTC_Start']

# %%
df['Open_change'] = df['Open'] - df['Open'].shift(1)
df['High_change'] = df['High'] - df['High'].shift(1)
df['Low_change'] = df['Low'] - df['Low'].shift(1)
df['Close_change'] = df['Close'] - df['Close'].shift(1)
df = df.dropna()

# %%
df
# Out:
#                      new_label      Open      High       Low     Close  \
# Time_UTC_Start
# 2018-07-19 12:39:00          1   7422.10   7491.29   7416.14   7476.00
# 2018-07-19 13:39:00          1   7476.00   7521.86   7435.05   7460.77
# 2018-07-19 14:39:00          0   7460.77   7491.57   7380.00   7394.32
# 2018-07-19 15:39:00          0   7397.96   7431.19   7373.25   7406.95
# 2018-07-19 16:39:00          1   7406.95   7432.87   7352.00   7427.85
# ...                        ...       ...       ...       ...       ...
# 2022-05-07 03:39:00          0  35823.05  35895.61  35755.85  35814.49
# 2022-05-07 04:39:00          0  35814.49  35897.44  35722.24  35821.68
# 2022-05-07 05:39:00          0  35821.69  35909.75  35794.31  35858.19
# 2022-05-07 06:39:00          0  35858.19  35912.00  35790.02  35902.74
# 2022-05-07 07:39:00          0  35902.75  35956.51  35880.47  35951.69
#
#                           Volumn  Quote_asset_volume  Number_of_trades  \
# Time_UTC_Start
# 2018-07-19 12:39:00  2503.435824        1.864360e+07           13841.0
# 2018-07-19 13:39:00  2828.531733        2.112726e+07           14906.0
# 2018-07-19 14:39:00  2064.560674        1.541043e+07           11528.0
# 2018-07-19 15:39:00  2923.943374        2.164442e+07           12951.0
# 2018-07-19 16:39:00  2251.185717        1.663907e+07           12357.0
# ...                          ...                 ...               ...
# 2022-05-07 03:39:00   970.311790        3.476291e+07           23856.0
# 2022-05-07 04:39:00   989.732570        3.544653e+07           24154.0
# 2022-05-07 05:39:00   814.217850        2.919114e+07           22472.0
# 2022-05-07 06:39:00  1330.810940        4.768683e+07           24694.0
# 2022-05-07 07:39:00   368.392130        1.323538e+07            7430.0
#
#                      Taker_buy_base_asset_volume  \
# Time_UTC_Start
# 2018-07-19 12:39:00                  1566.110620
# 2018-07-19 13:39:00                  1534.280510
# 2018-07-19 14:39:00                   907.501465
# 2018-07-19 15:39:00                  1518.376834
# 2018-07-19 16:39:00                  1275.285013
# ...                                          ...
# 2022-05-07 03:39:00                   482.353610
# 2022-05-07 04:39:00                   445.450930
# 2022-05-07 05:39:00                   409.742390

#  'Open',
#  'High',
#  'Low',
#  'Close',
#  'Volumn',
#  'Quote_asset_volume',
#  'Number_of_trades',
#  'Taker_buy_base_asset_volume',
#  'Taker_buy_quote_asset_volume',
#  'label',
#  'Open_change',
#  'High_change',
#  'Low_change',
#  'Close_change']

# %%
base_cols = base_cols[5:]

# %%
base_cols.remove('label')

# %%
import gc
def base_feat(df, base_cols=[], 
                  time_delta=1, 
                  window_lookback=[1, 5, 10, 60, 200],
                  agg_func=['min', 'max', 'mean', 'median', 'var']):
    """
    This func use for create formal features base on a list of columns
    Params:
        df (Pandas DF): dataframe input
        base_cols (list): list of columns you want to create feature by this function
        time_delta (int): time between 2 records (minutes)
        window_lookback (list): list of integer time the time_delta. For example time_delta = 15 window_lookback = [1, 2]
                                so the time lookback is 15 minutes and 15*2=30 minutes
        agg_func (list): aggregate func you use for rolling
    """
        
    for col in base_cols:
        for lookback in window_lookback:
            dict_agg_func = {'_'.join([agg, col, str(time_delta * lookback) + 'M']): agg for agg in agg_func}
            print(dict_agg_func)
            df_feat = df[col].shift(1).rolling(lookback).agg(dict_agg_func)
            df = pd.concat([df, df_feat], axis=1)
            del df_feat
            gc.collect()
    for col in df.columns:
        if str(time_delta) in col and 'var' in col:
            del df[col]
    df = df.dropna()
    return df

# %%
df_feat = base_feat(df, time_delta=60, base_cols=base_cols)
# Out:
# {'min_Volumn_60M': 'min', 'max_Volumn_60M': 'max', 'mean_Volumn_60M': 'mean', 'median_Volumn_60M': 'median', 'var_Volumn_60M': 'var'}
# {'min_Volumn_300M': 'min', 'max_Volumn_300M': 'max', 'mean_Volumn_300M': 'mean', 'median_Volumn_300M': 'median', 'var_Volumn_300M': 'var'}
# {'min_Volumn_600M': 'min', 'max_Volumn_600M': 'max', 'mean_Volumn_600M': 'mean', 'median_Volumn_600M': 'median', 'var_Volumn_600M': 'var'}
# {'min_Volumn_3600M': 'min', 'max_Volumn_3600M': 'max', 'mean_Volumn_3600M': 'mean', 'median_Volumn_3600M': 'median', 'var_Volumn_3600M': 'var'}
# {'min_Volumn_12000M': 'min', 'max_Volumn_12000M': 'max', 'mean_Volumn_12000M': 'mean', 'median_Volumn_12000M': 'median', 'var_Volumn_12000M': 'var'}
# {'min_Quote_asset_volume_60M': 'min', 'max_Quote_asset_volume_60M': 'max', 'mean_Quote_asset_volume_60M': 'mean', 'median_Quote_asset_volume_60M': 'median', 'var_Quote_asset_volume_60M': 'var'}
# {'min_Quote_asset_volume_300M': 'min', 'max_Quote_asset_volume_300M': 'max', 'mean_Quote_asset_volume_300M': 'mean', 'median_Quote_asset_volume_300M': 'median', 'var_Quote_asset_volume_300M': 'var'}
# {'min_Quote_asset_volume_600M': 'min', 'max_Quote_asset_volume_600M': 'max', 'mean_Quote_asset_volume_600M': 'mean', 'median_Quote_asset_volume_600M': 'median', 'var_Quote_asset_volume_600M': 'var'}
# {'min_Quote_asset_volume_3600M': 'min', 'max_Quote_asset_volume_3600M': 'max', 'mean_Quote_asset_volume_3600M': 'mean', 'median_Quote_asset_volume_3600M': 'median', 'var_Quote_asset_volume_3600M': 'var'}
# {'min_Quote_asset_volume_12000M': 'min', 'max_Quote_asset_volume_12000M': 'max', 'mean_Quote_asset_volume_12000M': 'mean', 'median_Quote_asset_volume_12000M': 'median', 'var_Quote_asset_volume_12000M': 'var'}
# {'min_Number_of_trades_60M': 'min', 'max_Number_of_trades_60M': 'max', 'mean_Number_of_trades_60M': 'mean', 'median_Number_of_trades_60M': 'median', 'var_Number_of_trades_60M': 'var'}
# {'min_Number_of_trades_300M': 'min', 'max_Number_of_trades_300M': 'max', 'mean_Number_of_trades_300M': 'mean', 'median_Number_of_trades_300M': 'median', 'var_Number_of_trades_300M': 'var'}
# {'min_Number_of_trades_600M': 'min', 'max_Number_of_trades_600M': 'max', 'mean_Number_of_trades_600M': 'mean', 'median_Number_of_trades_600M': 'median', 'var_Number_of_trades_600M': 'var'}
# {'min_Number_of_trades_3600M': 'min', 'max_Number_of_trades_3600M': 'max', 'mean_Number_of_trades_3600M': 'mean', 'median_Number_of_trades_3600M': 'median', 'var_Number_of_trades_3600M': 'var'}
# {'min_Number_of_trades_12000M': 'min', 'max_Number_of_trades_12000M': 'max', 'mean_Number_of_trades_12000M': 'mean', 'median_Number_of_trades_12000M': 'median', 'var_Number_of_trades_12000M': 'var'}
# {'min_Taker_buy_base_asset_volume_60M': 'min', 'max_Taker_buy_base_asset_volume_60M': 'max', 'mean_Taker_buy_base_asset_volume_60M': 'mean', 'median_Taker_buy_base_asset_volume_60M': 'median', 'var_Taker_buy_base_asset_volume_60M': 'var'}
# {'min_Taker_buy_base_asset_volume_300M': 'min', 'max_Taker_buy_base_asset_volume_300M': 'max', 'mean_Taker_buy_base_asset_volume_300M': 'mean', 'median_Taker_buy_base_asset_volume_300M': 'median', 'var_Taker_buy_base_asset_volume_300M': 'var'}
# {'min_Taker_buy_base_asset_volume_600M': 'min', 'max_Taker_buy_base_asset_volume_600M': 'max', 'mean_Taker_buy_base_asset_volume_600M': 'mean', 'median_Taker_buy_base_asset_volume_600M': 'median', 'var_Taker_buy_base_asset_volume_600M': 'var'}
# {'min_Taker_buy_base_asset_volume_3600M': 'min', 'max_Taker_buy_base_asset_volume_3600M': 'max', 'mean_Taker_buy_base_asset_volume_3600M': 'mean', 'median_Taker_buy_base_asset_volume_3600M': 'median', 'var_Taker_buy_base_asset_volume_3600M': 'var'}
# {'min_Taker_buy_base_asset_volume_12000M': 'min', 'max_Taker_buy_base_asset_volume_12000M': 'max', 'mean_Taker_buy_base_asset_volume_12000M': 'mean', 'median_Taker_buy_base_asset_volume_12000M': 'median', 'var_Taker_buy_base_asset_volume_12000M': 'var'}
# {'min_Taker_buy_quote_asset_volume_60M': 'min', 'max_Taker_buy_quote_asset_volume_60M': 'max', 'mean_Taker_buy_quote_asset_volume_60M': 'mean', 'median_Taker_buy_quote_asset_volume_60M': 'median', 'var_Taker_buy_quote_asset_volume_60M': 'var'}
# {'min_Taker_buy_quote_asset_volume_300M': 'min', 'max_Taker_buy_quote_asset_volume_300M': 'max', 'mean_Taker_buy_quote_asset_volume_300M': 'mean', 'median_Taker_buy_quote_asset_volume_300M': 'median', 'var_Taker_buy_quote_asset_volume_300M': 'var'}
# {'min_Taker_buy_quote_asset_volume_600M': 'min', 'max_Taker_buy_quote_asset_volume_600M': 'max', 'mean_Taker_buy_quote_asset_volume_600M': 'mean', 'median_Taker_buy_quote_asset_volume_600M': 'median', 'var_Taker_buy_quote_asset_volume_600M': 'var'}
# {'min_Taker_buy_quote_asset_volume_3600M': 'min', 'max_Taker_buy_quote_asset_volume_3600M': 'max', 'mean_Taker_buy_quote_asset_volume_3600M': 'mean', 'median_Taker_buy_quote_asset_volume_3600M': 'median', 'var_Taker_buy_quote_asset_volume_3600M': 'var'}
# {'min_Taker_buy_quote_asset_volume_12000M': 'min', 'max_Taker_buy_quote_asset_volume_12000M': 'max', 'mean_Taker_buy_quote_asset_volume_12000M': 'mean', 'median_Taker_buy_quote_asset_volume_12000M': 'median', 'var_Taker_buy_quote_asset_volume_12000M': 'var'}
# {'min_Open_change_60M': 'min', 'max_Open_change_60M': 'max', 'mean_Open_change_60M': 'mean', 'median_Open_change_60M': 'median', 'var_Open_change_60M': 'var'}
# {'min_Open_change_300M': 'min', 'max_Open_change_300M': 'max', 'mean_Open_change_300M': 'mean', 'median_Open_change_300M': 'median', 'var_Open_change_300M': 'var'}
# {'min_Open_change_600M': 'min', 'max_Open_change_600M': 'max', 'mean_Open_change_600M': 'mean', 'median_Open_change_600M': 'median', 'var_Open_change_600M': 'var'}
# {'min_Open_change_3600M': 'min', 'max_Open_change_3600M': 'max', 'mean_Open_change_3600M': 'mean', 'median_Open_change_3600M': 'median', 'var_Open_change_3600M': 'var'}
# {'min_Open_change_12000M': 'min', 'max_Open_change_12000M': 'max', 'mean_Open_change_12000M': 'mean', 'median_Open_change_12000M': 'median', 'var_Open_change_12000M': 'var'}
# {'min_High_change_60M': 'min', 'max_High_change_60M': 'max', 'mean_High_change_60M': 'mean', 'median_High_change_60M': 'median', 'var_High_change_60M': 'var'}
# {'min_High_change_300M': 'min', 'max_High_change_300M': 'max', 'mean_High_change_300M': 'mean', 'median_High_change_300M': 'median', 'var_High_change_300M': 'var'}
# {'min_High_change_600M': 'min', 'max_High_change_600M': 'max', 'mean_High_change_600M': 'mean', 'median_High_change_600M': 'median', 'var_High_change_600M': 'var'}
# {'min_High_change_3600M': 'min', 'max_High_change_3600M': 'max', 'mean_High_change_3600M': 'mean', 'median_High_change_3600M': 'median', 'var_High_change_3600M': 'var'}
# {'min_High_change_12000M': 'min', 'max_High_change_12000M': 'max', 'mean_High_change_12000M': 'mean', 'median_High_change_12000M': 'median', 'var_High_change_12000M': 'var'}
# {'min_Low_change_60M': 'min', 'max_Low_change_60M': 'max', 'mean_Low_change_60M': 'mean', 'median_Low_change_60M': 'median', 'var_Low_change_60M': 'var'}
# {'min_Low_change_300M': 'min', 'max_Low_change_300M': 'max', 'mean_Low_change_300M': 'mean', 'median_Low_change_300M': 'median', 'var_Low_change_300M': 'var'}
# {'min_Low_change_600M': 'min', 'max_Low_change_600M': 'max', 'mean_Low_change_600M': 'mean', 'median_Low_change_600M': 'median', 'var_Low_change_600M': 'var'}
# {'min_Low_change_3600M': 'min', 'max_Low_change_3600M': 'max', 'mean_Low_change_3600M': 'mean', 'median_Low_change_3600M': 'median', 'var_Low_change_3600M': 'var'}
# {'min_Low_change_12000M': 'min', 'max_Low_change_12000M': 'max', 'mean_Low_change_12000M': 'mean', 'median_Low_change_12000M': 'median', 'var_Low_change_12000M': 'var'}
# {'min_Close_change_60M': 'min', 'max_Close_change_60M': 'max', 'mean_Close_change_60M': 'mean', 'median_Close_change_60M': 'median', 'var_Close_change_60M': 'var'}
# {'min_Close_change_300M': 'min', 'max_Close_change_300M': 'max', 'mean_Close_change_300M': 'mean', 'median_Close_change_300M': 'median', 'var_Close_change_300M': 'var'}
# {'min_Close_change_600M': 'min', 'max_Close_change_600M': 'max', 'mean_Close_change_600M': 'mean', 'median_Close_change_600M': 'median', 'var_Close_change_600M': 'var'}
# {'min_Close_change_3600M': 'min', 'max_Close_change_3600M': 'max', 'mean_Close_change_3600M': 'mean', 'median_Close_change_3600M': 'median', 'var_Close_change_3600M': 'var'}
# {'min_Close_change_12000M': 'min', 'max_Close_change_12000M': 'max', 'mean_Close_change_12000M': 'mean', 'median_Close_change_12000M': 'median', 'var_Close_change_12000M': 'var'}

# %%
df_feat
# Out:
#                      new_label      Open      High       Low     Close  \
# Time_UTC_Start
# 2018-07-27 20:39:00          0   8228.62   8260.00   8222.54   8256.42
# 2018-07-27 21:39:00          1   8257.98   8277.20   8219.00   8238.99
# 2018-07-27 22:39:00          1   8238.93   8270.01   8128.00   8156.55
# 2018-07-27 23:39:00          1   8156.55   8225.30   8130.00   8176.51
# 2018-07-28 00:39:00          1   8176.51   8195.89   8156.51   8183.27
# ...                        ...       ...       ...       ...       ...
# 2022-05-07 03:39:00          0  35823.05  35895.61  35755.85  35814.49
# 2022-05-07 04:39:00          0  35814.49  35897.44  35722.24  35821.68
# 2022-05-07 05:39:00          0  35821.69  35909.75  35794.31  35858.19
# 2022-05-07 06:39:00          0  35858.19  35912.00  35790.02  35902.74
# 2022-05-07 07:39:00          0  35902.75  35956.51  35880.47  35951.69
#
#                           Volumn  Quote_asset_volume  Number_of_trades  \
# Time_UTC_Start
# 2018-07-27 20:39:00  1015.505793        8.368948e+06            5782.0
# 2018-07-27 21:39:00  1076.576098        8.880155e+06            6065.0
# 2018-07-27 22:39:00  2031.897711        1.667219e+07           10383.0
# 2018-07-27 23:39:00  1440.677019        1.178337e+07            8100.0
# 2018-07-28 00:39:00   978.116916        7.998172e+06            5798.0
# ...                          ...                 ...               ...
# 2022-05-07 03:39:00   970.311790        3.476291e+07           23856.0
# 2022-05-07 04:39:00   989.732570        3.544653e+07           24154.0
# 2022-05-07 05:39:00   814.217850        2.919114e+07           22472.0
# 2022-05-07 06:39:00  1330.810940        4.768683e+07           24694.0
# 2022-05-07 07:39:00   368.392130        1.323538e+07            7430.0
#
#                      Taker_buy_base_asset_volume  \
# Time_UTC_Start
# 2018-07-27 20:39:00                   570.572346
  \
# Time_UTC_Start
# 2018-07-27 20:39:00                -0.506449                  0.194954
# 2018-07-27 21:39:00                -0.506449                  0.187139
# 2018-07-27 22:39:00                -0.506449                  0.186442
# 2018-07-27 23:39:00                -0.506449                  0.181376
# 2018-07-28 00:39:00                -0.506449                  0.183698
# ...                                      ...                       ...
# 2022-05-07 03:39:00                 0.487015                 -1.392658
# 2022-05-07 04:39:00                 0.487015                 -1.393799
# 2022-05-07 05:39:00                 0.487015                 -1.326546
# 2022-05-07 06:39:00                 0.487015                 -1.275075
# 2022-05-07 07:39:00                 0.487015                 -1.275186
#
#                      median_Close_change_12000M  var_Close_change_12000M
# Time_UTC_Start
# 2018-07-27 20:39:00                   -0.171609                -0.559920
# 2018-07-27 21:39:00                   -0.171609                -0.560023
# 2018-07-27 22:39:00                   -0.171609                -0.560018
# 2018-07-27 23:39:00                   -0.171609                -0.559879
# 2018-07-28 00:39:00                   -0.171609                -0.559869
# ...                                         ...                      ...
# 2022-05-07 03:39:00                   -1.076026                -0.032465
# 2022-05-07 04:39:00                   -1.076026                -0.032471
# 2022-05-07 05:39:00                   -0.967306                -0.034316
# 2022-05-07 06:39:00                   -0.872176                -0.034768
# 2022-05-07 07:39:00                   -0.872176                -0.034771
#
# [32798 rows x 213 columns]

# %% [markdown]
# ### train test split

# %%
X, y = df_feat[feat], df_feat['new_label']
X_train, X_valid, X_test = X[:int(df_feat.shape[0]*0.7)], X[int(df_feat.shape[0]*0.7):int(df_feat.shape[0]*0.85)], X[int(df_feat.shape[0]*0.85):]
y_train, y_valid, y_test = y[:int(df_feat.shape[0]*0.7)], y[int(df_feat.shape[0]*0.7):int(df_feat.shape[0]*0.85)], y[int(df_feat.shape[0]*0.85):]

# %% [markdown]
# ## logistic model

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression(penalty='l2', dual=False, tol=0.0001, C=0.1, fit_intercept=True, intercept_scaling=1, class_weight=None, random_state=1234, solver='lbfgs', max_iter=100, multi_class='auto', verbose=1)

# %%
clf.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\ADMIN\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s finished
# LogisticRegression(C=0.1, random_state=1234, verbose=1)

# %%
y_pred_val = clf.predict_proba(X_valid)

# %%
y_pred_val = y_pred_val[:, 1]

# %%
plt.hist(y_pred_val, bins=50)
# Out:
# (array([681., 237., 165., 115., 116., 109.,  86.,  84.,  81.,  61.,  59.,
#          46.,  48.,  40.,  45.,  49.,  46.,  50.,  43.,  64.,  34.,  38.,
#          65.,  41.,  54.,  42.,  47.,  44.,  50.,  35.,  48.,  54.,  50.,
#          52.,  31.,  58.,  52.,  62.,  59.,  75.,  78.,  79.,  84.,  69.,
#          87., 114., 121., 160., 202., 665.]),
#  array([3.82919776e-10, 1.99999972e-02, 3.99999940e-02, 5.99999909e-02,
#         7.99999877e-02, 9.99999845e-02, 1.19999981e-01, 1.39999978e-01,
#         1.59999975e-01, 1.79999972e-01, 1.99999969e-01, 2.19999966e-01,
#         2.39999962e-01, 2.59999959e-01, 2.79999956e-01, 2.99999953e-01,
#         3.19999950e-01, 3.39999946e-01, 3.59999943e-01, 3.79999940e-01,
#         3.99999937e-01, 4.19999934e-01, 4.39999931e-01, 4.59999927e-01,
#         4.79999924e-01, 4.99999921e-01, 5.19999918e-01, 5.39999915e-01,
# 514                    -0.560697               -0.569471
# 515                    -0.554940               -0.569667
# 516                    -0.554940               -0.569666
# 517                    -0.554940               -0.569778
# ...                          ...                     ...
# 23502                   1.101320                1.411959
# 23503                   1.206974                1.412678
# 23504                   1.101320                1.429929
# 23505                   1.101320                1.432806
# 23506                   0.915071                1.396061
#
#        min_Close_change_7500M  max_Close_change_7500M  \
# 513                  0.628894               -0.626810
# 514                  0.628894               -0.626810
# 515                  0.628894               -0.626810
# 516                  0.628894               -0.626810
# 517                  0.628894               -0.626810
# ...                       ...                     ...
# 23502               -0.811399                1.227638
# 23503               -0.811399                1.227638
# 23504               -0.811399                1.227638
# 23505               -0.811399                1.227638
# 23506               -0.811399                1.227638
#
#        mean_Close_change_7500M  median_Close_change_7500M  \
# 513                  -0.297912                  -0.607443
# 514                  -0.306176                  -0.607443
# 515                  -0.302018                  -0.607443
# 516                  -0.304409                  -0.619120
# 517                  -0.304652                  -0.619120
# ...                        ...                        ...
# 23502                 1.049214                   3.458558
# 23503                 1.143182                   3.642469
# 23504                 0.963413                   3.458558
# 23505                 0.895910                   3.458558
# 23506                 0.799792                   3.395795
#
#        var_Close_change_7500M
# 513                 -0.624311
# 514                 -0.624252
# 515                 -0.624240
# 516                 -0.624238
# 517                 -0.624239
# ...                       ...
# 23502                1.778602
# 23503                1.776621
# 23504                1.787001
# 23505                1.789437
# 23506                1.790629
#
# [22740 rows x 216 columns]

# %%
from lightgbm import LGBMClassifier
model = LGBMClassifier()

# %%
X, y = df_feat[feat], df_feat['new_label']
X_train, X_valid, X_test = X[:int(df_feat.shape[0]*0.7)], X[int(df_feat.shape[0]*0.7):int(df_feat.shape[0]*0.85)], X[int(df_feat.shape[0]*0.85):]
y_train, y_valid, y_test = y[:int(df_feat.shape[0]*0.7)], y[int(df_feat.shape[0]*0.7):int(df_feat.shape[0]*0.85)], y[int(df_feat.shape[0]*0.85):]

# %%
params = {'objective': 'binary',
                      'metric': ['auc'],
                      'boosting':'gbdt',
                      'num_boost_round':1000,
                      'early_stopping_rounds':10,
                      'learning_rate': 0.1,
                      'max_depth': 4,
                      'num_leaves': 16,
                      'feature_fraction': 0.8,
#                       'bagging_fraction': 0.8,
#                       'min_data_in_leaf': 10,
                      'verbosity': 1}

# %%
import lightgbm as lgb
train_data = lgb.Dataset(X_train, y_train)
valid_data = lgb.Dataset(X_valid, y_valid, reference=train_data)

# %%
model = lgb.train(params, train_data,                     
                  valid_sets=[train_data, valid_data],
                  valid_names=['train', 'valid'])
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Info] Number of positive: 12193, number of negative: 10765
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027567 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 49999
# [LightGBM] [Info] Number of data points in the train set: 22958, number of used features: 198
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.531100 -> initscore=0.124562
# [LightGBM] [Info] Start training from score 0.124562
# [1]	train's auc: 0.751448	valid's auc: 0.818002
# Training until validation scores don't improve for 10 rounds
# [2]	train's auc: 0.761526	valid's auc: 0.831603
# [3]	train's auc: 0.765961	valid's auc: 0.833595
# [4]	train's auc: 0.766621	valid's auc: 0.830861
# [5]	train's auc: 0.767963	valid's auc: 0.831819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]
# 6                     mean_High_change_3600M      1299.702100
# 7                            max_Volumn_600M       957.619221
# 8   median_Taker_buy_base_asset_volume_3600M       425.305637
# 9      max_Taker_buy_base_asset_volume_3600M       351.257199
# 10                    mean_Open_change_3600M       300.860009
# 11                       median_Volumn_3600M       299.638149
# 12                       min_Low_change_600M       294.234699
# 13                           var_Volumn_300M       281.520300
# 14                      min_Open_change_600M       251.230904
# 15                         mean_Volumn_3600M       245.153456
# 16                     min_High_change_3600M       220.784156
# 17                  mean_Close_change_12000M       172.684101
# 18                  median_High_change_3600M       161.954602
# 19    mean_Taker_buy_base_asset_volume_3600M       159.278101
# 20                 max_Number_of_trades_300M       148.126204
# 21                          mean_Volumn_600M       148.058798
# 22      max_Taker_buy_base_asset_volume_300M       142.950800
# 23                 median_Close_change_3600M       138.096500
# 24     max_Taker_buy_quote_asset_volume_600M       135.002819
# 25                       max_Low_change_300M       125.598899
# 26                       max_Low_change_600M       124.436399
# 27       min_Taker_buy_base_asset_volume_60M       121.854399
# 28              min_Quote_asset_volume_3600M       115.824400
# 29                  median_Open_change_3600M       107.890427
# 30                     min_Open_change_3600M       107.702600
# 31                      min_Low_change_3600M        99.036678
# 32                          max_Volumn_3600M        97.445939
# 33   median_Taker_buy_base_asset_volume_600M        95.407301
# 34                min_Quote_asset_volume_60M        85.873401
# 35                          min_Volumn_3600M        85.200901
# 36                   median_High_change_600M        82.054602
# 37                     max_High_change_3600M        81.006411
# 38                 min_Number_of_trades_600M        76.370600
# 39                  median_Low_change_12000M        75.578501
# 40                min_Number_of_trades_3600M        75.412899
# 41                       var_Low_change_300M        73.774801
# 42                    mean_Low_change_12000M        72.085001
# 43                            min_Volumn_60M        69.151499
# 44                   median_Low_change_3600M        64.800148
# 45                max_Number_of_trades_3600M        64.436998
# 46                     max_Open_change_3600M        64.249500
# 47                       min_Low_change_300M        62.555599
# 48           median_Quote_asset_volume_3600M        62.257599
# 49                      max_High_change_600M        61.592201
#
#     importance_split
# 0                 38
# 1                 34
# 2                 39
# 3                 34
# 4                 21
# 5                 33
# 6                 20
# 7                 19
# 8                 15
# 9                  9
# 10                 6
# 11                12
# 12                10
# 13                 9
# 14                10
# 15                 8
# 16                 8
# 17                 6
# 18                 6
# 19                 6
# 20                 6
# 21                 4
# 22                 5
# 23                 6
# 24                 6
# 25                 6
# 26                 5
# 27                 6
# 28                 4
# 29                 7
# 30                 5
# 31                 5
# 32                 3
# 33                 3
# 34                 4
# 35                 3
# 36                 4
# 37                 5
# 38                 3
# 39                 3
# 40                 4
# 41                 3
# 42                 4
# 43                 2
# 44                 5
# 45                 2
# 46                 3
# 47                 4
# 48                 2
# 49                 3

# %%
y_test_t = (model.predict(X_test) >= 0.56) * 1
y_train_t = (model.predict(X_train) >= 0.56) * 1
y_valid_t = (model.predict(X_valid) >= 0.56) * 1

# %%
pred
# Out:
# array([0.58061311, 0.7586601 , 0.77491791, ..., 0.40482021, 0.42248148,
#        0.44172924])

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_train, y_train_t))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.78      0.72     10765
#            1       0.77      0.65      0.70     12193
#
#     accuracy                           0.71     22958
#    macro avg       0.72      0.71      0.71     22958
# weighted avg       0.72      0.71      0.71     22958

# %%
plt.hist(model.predict(X_test), bins=20)
# Out:
# (array([255., 300., 189., 208., 220., 219., 270., 324., 222., 178., 185.,
#         253., 279., 402., 256., 226., 247., 181., 225., 236.]),
#  array([0.04952924, 0.0949909 , 0.14045257, 0.18591423, 0.2313759 ,
#         0.27683756, 0.32229922, 0.36776089, 0.41322255, 0.45868422,
#         0.50414588, 0.54960755, 0.59506921, 0.64053088, 0.68599254,
#         0.73145421, 0.77691587, 0.82237753, 0.8678392 , 0.91330086,
#         0.95876253]),
#  <BarContainer object of 20 artists>)

# %%
roc_auc_score(df_feat['label'][int(df_feat.shape[0]*0.85):], pred)
# Out:
# 0.48544645235283557

# %%
roc_auc_score(y_test, pred)
# Out:
# 0.8411361296776906

# %% [markdown]
# ## model for the residual

# %%
resid = pd.read_csv('./residual.csv')

# %%
resid.index = resid.Time_UTC_Start

# %%
resid = resid.dropna()

# %%
resid
# Out:
#                           Time_UTC_Start       resid
# Time_UTC_Start
# 2018-07-19 10:39:00  2018-07-19 10:39:00   20.399253
# 2018-07-19 11:39:00  2018-07-19 11:39:00   44.687776
# 2018-07-19 12:39:00  2018-07-19 12:39:00   58.912020
# 2018-07-19 13:39:00  2018-07-19 13:39:00  119.046409
# 2018-07-19 14:39:00  2018-07-19 14:39:00  101.936594
# ...                                  ...         ...
# 2022-05-07 03:39:00  2022-05-07 03:39:00 -175.444066
# 2022-05-07 04:39:00  2022-05-07 04:39:00 -220.661329
# 2022-05-07 05:39:00  2022-05-07 05:39:00 -158.834902
# 2022-05-07 06:39:00  2022-05-07 06:39:00 -200.925333
# 2022-05-07 07:39:00  2022-05-07 07:39:00  -25.401807
#
# [33310 rows x 2 columns]

# %%
plt.hist(resid.resid, bins=20)
# Out:
# (array([2.0000e+00, 3.0000e+00, 2.0000e+00, 6.0000e+00, 1.3000e+01,
#         2.6000e+01, 4.5000e+01, 1.0000e+02, 2.4800e+02, 5.9200e+02,
#         1.6210e+03, 1.8524e+04, 9.5300e+03, 1.6600e+03, 5.9200e+02,
#         2.4300e+02, 7.0000e+01, 2.2000e+01, 8.0000e+00, 3.0000e+00]),
#  array([-7939.49922961, -7273.82640852, -6608.15358743, -5942.48076633,
#         -5276.80794524, -4611.13512415, -3945.46230305, -3279.78948196,
#         -2614.11666087, -1948.44383977, -1282.77101868,  -617.09819759,
#            48.5746235 ,   714.2474446 ,  1379.92026569,  2045.59308678,
#          2711.26590788,  3376.93872897,  4042.61155006,  4708.28437116,
#          5373.95719225]),
#  <BarContainer object of 20 artists>)

# %%
r = resid.resid - resid.resid.shift(1)

# %%
sum(r[1:])/(resid.shape[0]-1)
# Out:
# -0.0013750355798276342

# %%
from statsmodels.tsa.stattools import adfuller
from numpy import log
result = adfuller(resid.resid.dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# 2022-05-07 05:39:00  2022-05-07 05:39:00 -158.834902
# 2022-05-07 06:39:00  2022-05-07 06:39:00 -200.925333
# 2022-05-07 07:39:00  2022-05-07 07:39:00  -25.401807
#
# [32798 rows x 215 columns]

# %%
X, y = df_r[feat], df_r['resid']
X_train, X_valid, X_test = X[:int(df_r.shape[0]*0.7)], X[int(df_r.shape[0]*0.7):int(df_r.shape[0]*0.85)], X[int(df_r.shape[0]*0.85):]
y_train, y_valid, y_test = y[:int(df_r.shape[0]*0.7)], y[int(df_r.shape[0]*0.7):int(df_r.shape[0]*0.85)], y[int(df_r.shape[0]*0.85):]

# %%
linear_r = Ridge(alpha=1.1e4)

# %%
linear_r.fit(X_train, y_train)
# Out:
# Ridge(alpha=11000.0)

# %%
def take_the_error(model_regression, training_set, valid_set, test_set):
    X_train, y_train = training_set[0], training_set[1]
    X_valid, y_valid = valid_set[0], valid_set[1]
    X_test, y_test = test_set[0], test_set[1]
    train_pred = model_regression.predict(X_train)
    valid_pred = model_regression.predict(X_valid)
    test_pred = model_regression.predict(X_test)
    train = (((train_pred * y_train) >= 0) * 1).sum()/len(y_train)
    valid = (((valid_pred * y_valid) >= 0) * 1).sum()/len(y_valid)
    test = (((test_pred * y_test) >= 0) * 1).sum()/len(y_test)
    mse_train, mse_valid, mse_test = mean_squared_error(y_train, train_pred), mean_squared_error(y_valid, valid_pred), mean_squared_error(y_test, test_pred)
    rmse_train, rmse_valid, rmse_test = math.sqrt(mse_train), math.sqrt(mse_valid), math.sqrt(mse_test)
    print(f'Train error is: MSE= {mse_train}, RMSE={rmse_train}, ACC={train}')
    print(f'Valid error is: MSE= {mse_valid}, RMSE={rmse_valid}, ACC={valid}')
    print(f'Test error is: MSE= {mse_test}, RMSE={rmse_test}, ACC={test}')
    return ((train_pred * y_train) >= 0) * 1, ((valid_pred * y_valid) >= 0) * 1, ((test_pred * y_test) >= 0) * 1

# %%
y_train_r, y_valid_r, y_test_r = take_the_error(linear_r, [X_train, y_train], [X_valid, y_valid], [X_test, y_test])
# Out:
# Train error is: MSE= 126031.72763032209, RMSE=355.0094754092095, ACC=0.6374684205941284
# Valid error is: MSE= 797935.0721370382, RMSE=893.2721153920781, ACC=0.6
# Test error is: MSE= 570136.8607592323, RMSE=755.0740763390254, ACC=0.5603658536585366

# %% [markdown]
# ## the last evaluation

# %%
y_train, y_valid, y_test = df_feat['label'][:int(df_feat.shape[0]*0.7)], y[int(df_feat.shape[0]*0.7):int(df_feat.shape[0]*0.85)], y[int(df_feat.shape[0]*0.85):]

# %%
# Out:
# Time_UTC_Start
# 2018-07-27 20:39:00    0
# 2018-07-27 21:39:00    1
# 2018-07-27 22:39:00    1
# 2018-07-27 23:39:00    1
# 2018-07-28 00:39:00    1
#                       ..
# 2021-03-20 19:39:00    1
# 2021-03-20 20:39:00    1
# 2021-03-20 21:39:00    1
# 2021-03-20 22:39:00    1
# 2021-03-20 23:39:00    1
# Name: new_label, Length: 22958, dtype: int64
